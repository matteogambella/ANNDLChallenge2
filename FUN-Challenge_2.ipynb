# %% [markdown]
# # Initial Setup

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np

# Set the seed for random operations. 
# Letting experiments to be reproducible. 
SEED = 1234
tf.random.set_seed(SEED) 
np.random.seed(SEED)

# Get current working directory
cwd = os.getcwd()

# %%
# Mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Dec 10 18:02:27 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Dataset Retrieval

# %%
# Option to set to true the first time to RETRIEVE the dataset and create the
# folder structure. If set to false it expects the dataset to be already 
# splitted and zipped in your drive in the directory "Challenge_2".
SPLIT_DATASET = True

# This option let you use your dataset_split.json file, that must be located in 
# your drive in the directory "Challenge_2", for the dataset split.
# Is considered only if SPLIT_DATASET == True since if SPLIT_DATASET == 
# False the dataset is expected to be already splitted and zipped in your
# drive in the directory "Challenge_2".
LOAD_FROM_JSON = False

# %%
! rm dataset_split.json
# Out:
# rm: cannot remove 'dataset_split.json': No such file or directory

# %% [markdown]
# ### Cells executed if: SPLIT_DATASET = True

# %%
if SPLIT_DATASET == True:
  ! unzip '/content/drive/My Drive/Challenge_2/Development_Dataset.zip'
# Out:
# Archive:  /content/drive/My Drive/Challenge_2/Development_Dataset.zip
#   inflating: Development_Dataset/LICENSE.txt
#    creating: Development_Dataset/Test_Dev/
#    creating: Development_Dataset/Test_Dev/Bipbip/
#    creating: Development_Dataset/Test_Dev/Bipbip/Haricot/
#    creating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_00211.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_00581.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_00721.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_00951.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_01341.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_02421.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_02781.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_02841.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_02901.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_03691.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_06581.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_06751.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_07181.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_07331.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Haricot/Images/Bipbip_haricot_im_07421.jpg
#    creating: Development_Dataset/Test_Dev/Bipbip/Mais/
#    creating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_01931.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_02211.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_03621.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_04121.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_05521.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_06381.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_06831.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_07611.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_07681.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_09091.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_09571.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_09781.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_10441.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_10941.jpg
#   inflating: Development_Dataset/Test_Dev/Bipbip/Mais/Images/Bipbip_mais_im_11021.jpg
#    creating: Development_Dataset/Test_Dev/Pead/
#    creating: Development_Dataset/Test_Dev/Pead/Haricot/
#    creating: Development_Dataset/Test_Dev/Pead/Haricot/Images/
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00130_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00143_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00239_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00291_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00340_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00353_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00427_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00463_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00605_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00628_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00631_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00641_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00648_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00682_i750.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Haricot/Images/Pead_haricot_00704_i750.jpg
#    creating: Development_Dataset/Test_Dev/Pead/Mais/
#    creating: Development_Dataset/Test_Dev/Pead/Mais/Images/
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00173_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00206_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00229_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00308_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00346_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00387_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00395_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00427_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00459_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00556_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00584_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00595_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00679_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00723_i900.jpg
#   inflating: Development_Dataset/Test_Dev/Pead/Mais/Images/Pead_mais_00796_i900.jpg
#    creating: Development_Dataset/Test_Dev/Roseau/
#    creating: Development_Dataset/Test_Dev/Roseau/Haricot/
#    creating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0010_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0018_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0074_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0150_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0156_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0188_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0220_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0224_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0228_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0256_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0292_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0300_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0372_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0396_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Haricot/Images/Roseau_haricot_0414_false.png
#    creating: Development_Dataset/Test_Dev/Roseau/Mais/
#    creating: Development_Dataset/Test_Dev/Roseau/Mais/Images/
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0008_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0030_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0056_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0068_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0074_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0098_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0142_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0174_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0184_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0188_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0214_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0286_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0322_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0332_false.png
#   inflating: Development_Dataset/Test_Dev/Roseau/Mais/Images/Roseau_mais_0366_false.png
#    creating: Development_Dataset/Test_Dev/Weedelec/
#    creating: Development_Dataset/Test_Dev/Weedelec/Haricot/
#    creating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T114347-2.jpg
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T114419-14.jpg
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T114537-44.jpg
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T114558-52.jpg
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T114608-56.jpg
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T114726-86.jpg
#   inflating: Development_Dataset/Test_Dev/Weedelec/Haricot/Images/Weedelec_haricot_2019-09-25T
png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121821-298.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121846-308.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121906-316.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121917-320.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121924-323.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121932-326.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121937-328.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121945-331.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T121955-335.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122005-339.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122016-343.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122023-346.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122033-350.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122041-353.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122054-358.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122059-360.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122137-375.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122144-378.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122149-380.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122157-383.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122204-386.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122212-389.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122219-392.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122232-397.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122240-400.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122250-404.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122255-406.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122308-411.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122315-414.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122323-417.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122331-420.png
#   inflating: Development_Dataset/Training/Weedelec/Mais/Masks/Weedelec_mais_2019-09-25T122339-423.png

# %%
# -----------------------------
# Create the dataset_split.json 
# -----------------------------
if SPLIT_DATASET == True and LOAD_FROM_JSON == False:

  from PIL import Image
  import json
  
  VALIDATION_SPLIT = 0.15

  split = {}
  split['training'] = {}
  split['validation'] = {}

  teams = ['Bipbip', 'Pead', 'Roseau', 'Weedelec']
  plants = ['Haricot', 'Mais']

  # Random seed for reproducibility
  np.random.seed(SEED)

  for t in teams:

    split['training'][t] = {}
    split['validation'][t] = {}

    for p in plants:

      split['training'][t][p] = []      
      split['validation'][t][p] = []

      image_filenames = os.listdir('/content/Development_Dataset/Training/' + t + '/' + p + '/' + 'Images')
      # Order images files to get always the same split
      image_filenames = sorted(image_filenames)
          
      # Create training split
      for i in range(int(len(image_filenames) * (1 - VALIDATION_SPLIT))):
        image_name = image_filenames[i].split('.')
        split['training'][t][p].append(image_name)

      
      # Create validation split
      for j in range(i + 1, len(image_filenames)):
        image_name = image_filenames[j].split('.')
        split['validation'][t][p].append(image_name)

  with open(os.path.join(cwd, 'dataset_split.json'), 'w') as f:
    json.dump(split, f)

  ! cp '/content/dataset_split.json' '/content/drive/My Drive/Challenge_2/dataset_split.json'

# %%
split
# Out:
# {'training': {'Bipbip': {'Haricot': [['Bipbip_haricot_im_00321', 'jpg'],
#     ['Bipbip_haricot_im_00391', 'jpg'],
#     ['Bipbip_haricot_im_00451', 'jpg'],
#     ['Bipbip_haricot_im_00511', 'jpg'],
#     ['Bipbip_haricot_im_00651', 'jpg'],
#     ['Bipbip_haricot_im_00801', 'jpg'],
#     ['Bipbip_haricot_im_00871', 'jpg'],
#     ['Bipbip_haricot_im_01021', 'jpg'],
#     ['Bipbip_haricot_im_01091', 'jpg'],
#     ['Bipbip_haricot_im_01271', 'jpg'],
#     ['Bipbip_haricot_im_01451', 'jpg'],
#     ['Bipbip_haricot_im_01541', 'jpg'],
#     ['Bipbip_haricot_im_01631', 'jpg'],
#     ['Bipbip_haricot_im_01731', 'jpg'],
#     ['Bipbip_haricot_im_01821', 'jpg'],
#     ['Bipbip_haricot_im_01911', 'jpg'],
#     ['Bipbip_haricot_im_02171', 'jpg'],
#     ['Bipbip_haricot_im_02231', 'jpg'],
#     ['Bipbip_haricot_im_02301', 'jpg'],
#     ['Bipbip_haricot_im_02351', 'jpg'],
#     ['Bipbip_haricot_im_02531', 'jpg'],
#     ['Bipbip_haricot_im_02651', 'jpg'],
#     ['Bipbip_haricot_im_03041', 'jpg'],
#     ['Bipbip_haricot_im_03111', 'jpg'],
#     ['Bipbip_haricot_im_03231', 'jpg'],
#     ['Bipbip_haricot_im_03281', 'jpg'],
#     ['Bipbip_haricot_im_03291', 'jpg'],
#     ['Bipbip_haricot_im_03411', 'jpg'],
#     ['Bipbip_haricot_im_03461', 'jpg'],
#     ['Bipbip_haricot_im_03481', 'jpg'],
#     ['Bipbip_haricot_im_03531', 'jpg'],
#     ['Bipbip_haricot_im_03571', 'jpg'],
#     ['Bipbip_haricot_im_03611', 'jpg'],
#     ['Bipbip_haricot_im_03751', 'jpg'],
#     ['Bipbip_haricot_im_03841', 'jpg'],
#     ['Bipbip_haricot_im_03961', 'jpg'],
#     ['Bipbip_haricot_im_04031', 'jpg'],
#     ['Bipbip_haricot_im_04301', 'jpg'],
#     ['Bipbip_haricot_im_04401', 'jpg'],
#     ['Bipbip_haricot_im_04541', 'jpg'],
#     ['Bipbip_haricot_im_04591', 'jpg'],
#     ['Bipbip_haricot_im_04741', 'jpg'],
#     ['Bipbip_haricot_im_04791', 'jpg'],
#     ['Bipbip_haricot_im_04851', 'jpg'],
#     ['Bipbip_haricot_im_04991', 'jpg'],
#     ['Bipbip_haricot_im_05041', 'jpg'],
#     ['Bipbip_haricot_im_05111', 'jpg'],
#     ['Bipbip_haricot_im_05141', 'jpg'],
#     ['Bipbip_haricot_im_05231', 'jpg'],
#     ['Bipbip_haricot_im_05301', 'jpg'],
#     ['Bipbip_haricot_im_05351', 'jpg'],
#     ['Bipbip_haricot_im_05361', 'jpg'],
#     ['Bipbip_haricot_im_05411', 'jpg'],
#     ['Bipbip_haricot_im_05421', 'jpg'],
#     ['Bipbip_haricot_im_05461', 'jpg'],
#     ['Bipbip_haricot_im_05481', 'jpg'],
#     ['Bipbip_haricot_im_05531', 'jpg'],
#     ['Bipbip_haricot_im_05571', 'jpg'],
#     ['Bipbip_haricot_im_05741', 'jpg'],
#     ['Bipbip_haricot_im_05911', 'jpg'],
#     ['Bipbip_haricot_im_05991', 'jpg'],
#     ['Bipbip_haricot_im_06041', 'jpg'],
#     ['Bipbip_haricot_im_06101', 'jpg'],
#     ['Bipbip_haricot_im_06151', 'jpg'],
#     ['Bipbip_haricot_im_06241', 'jpg'],
#     ['Bipbip_haricot_im_06341', 'jpg'],
#     ['Bipbip_haricot_im_06401', 'jpg'],
#     ['Bipbip_haricot_im_06481', 'jpg'],
#     ['Bipbip_haricot_im_06531', 'jpg'],
#     ['Bipbip_haricot_im_06641', 'jpg'],
#     ['Bipbip_haricot_im_06691', 'jpg'],
#     ['Bipbip_haricot_im_06801', 'jpg'],
#     ['Bipbip_haricot_im_06851', 'jpg'],
#     ['Bipbip_haricot_im_06901', 'jpg'],
#     ['Bipbip_haricot_im_06941', 'jpg'],
#     ['Bipbip_haricot_im_07011', 'jpg']],
#    'Mais': [['Bipbip_mais_im_01391', 'jpg'],
#     ['Bipbip_mais_im_01461', 'jpg'],
#     ['Bipbip_mais_im_01511', 'jpg'],
#     ['Bipbip_mais_im_01561', 'jpg'],
#     ['Bipbip_mais_im_01601', 'jpg'],
#     ['Bipbip_mais_im_01681', 'jpg'],
#     ['Bipbip_mais_im_01751', 'jpg'],
#     ['Bipbip_mais_im_01871', 'jpg'],
#     ['Bipbip_mais_im_02151', 'jpg'],
#     ['Bipbip_mais_im_02281', 'jpg'],
#     ['Bipbip_mais_im_02371', 'jpg'],
#     ['Bipbip_mais_im_02411', 'jpg'],
#     ['Bipbip_mais_im_02461', 'jpg'],
#     ['Bipbip_mais_im_02511', 'jpg'],
#     ['Bipbip_mais_im_02691', 'jpg'],
#     ['Bipbip_mais_im_02731', 'jpg'],
#     ['Bipbip_mais_im_02781', 'jpg'],
#     ['Bipbip_mais_im_02891', 'jpg'],
#     ['Bipbip_mais_im_02941', 'jpg'],
#     ['Bipbip_mais_im_03121', 'jpg'],
#     ['Bipbip_mais_im_03181', 'jpg'],
#     ['Bipbip_mais_im_03231', 'jpg'],
#     ['Bipbip_mais_im_03291', 'jpg'],
#     ['Bipbip_mais_im_03391', 'jpg'],
#     ['Bipbip_mais_im_03511', 'jpg'],
#     ['Bipbip_mais_im_03581', 'jpg'],
#     ['Bipbip_mais_im_03691', 'jpg'],
#     ['Bipbip_mais_im_03751', 'jpg'],
#     ['Bipbip_mais_im_03811', 'jpg'],
#     ['Bipbip_mais_im_03871', 'jpg'],
#     ['Bipbip_mais_im_03921', 'jpg'],
#     ['Bipbip_mais_im_04031', 'jpg'],
#     ['Bipbip_mais_im_04501', 'jpg'],
#     ['Bipbip_mais_im_04561', 'jpg'],
#     ['Bipbip_mais_im_04621', 'jpg'],
#     ['Bipbip_mais_im_04671', 'jpg'],
#     ['Bipbip_mais_im_04781', 'jpg'],
#     ['Bipbip_mais_im_04911', 'jpg'],
#     ['Bipbip_mais_im_05031', 'jpg'],
#     ['Bipbip_mais_im_05221', 'jpg'],
#     ['Bipbip_mais_im_05281', 'jpg'],
#     ['Bipbip_mais_im_05381', 'jpg'],
#     ['Bipbip_mais_im_05451', 'jpg'],
#     ['Bipbip_mais_im_05691', 'jpg'],
#     ['Bipbip_mais_im_05801', 'jpg'],
#     ['Bipbip_mais_im_05871', 'jpg'],
#     ['Bipbip_mais_im_06071', 'jpg'],
#     ['Bipbip_mais_im_06141', 'jpg'],
#     ['Bipbip_mais_im_06541', 'jpg'],
#     ['Bipbip_mais_im_06691', 'jpg'],
#     ['Bipbip_mais_im_06961', 'jpg'],
#     ['Bipbip_mais_im_07041', 'jpg'],
#     ['Bipbip_mais_im_07181', 'jpg'],
#     ['Bipbip_mais_im_07271', 'jpg'],
#     ['Bipbip_mais_im_07351', 'jpg'],
#     ['Bipbip_mais_im_07451', 'jpg'],
#     ['Bipbip_mais_im_07531', 'jpg'],
#     ['Bipbip_mais_im_07761', 'jpg'],
#     ['Bipbip_mais_im_07831', 'jpg'],
#     ['Bipbip_mais_im_07911', 'jpg'],
#     ['Bipbip_mais_im_07991', 'jpg'],
#     ['Bipbip_mais_im_08061', 'jpg'],
#     ['Bipbip_mais_im_08121', 'jpg'],
#     ['Bipbip_mais_im_08261', 'jpg'],
#     ['Bipbip_mais_im_08321', 'jpg'],
#     ['Bipbip_mais_im_08381', 'jpg'],
#     ['Bipbip_mais_im_08441', 'jpg'],
#     ['Bipbip_mais_im_08511', 'jpg'],
#     ['Bipbip_mais_im_08581', 'jpg'],
#     ['Bipbip_mais_im_08661', 'jpg'],
#     ['Bipbip_mais_im_08731', 'jpg'],
#     ['Bipbip_mais_im_08811', 'jpg'],
#     ['Bipbip_mais_im_09231', 'jpg'],
#     ['Bipbip_mais_im_09311', 'jpg'],
#     ['Bipbip_mais_im_09501', 'jpg'],
#     ['Bipbip_mais_im_09641', 'jpg']]},
#   'Pead': {'Haricot': [['Pead_haricot_00006_i750', 'jpg'],
#     ['Pead_haricot_00016_i750', 'jpg'],
#     ['Pead_haricot_00047_i750', 'jpg'],
#     ['Pead_haricot_00066_i750', 'jpg'],
#     ['Pead_haricot_00069_i750', 'jpg'],
#     ['Pead_haricot_00079_i750', 'jpg'],
#     ['Pead_haricot_00089_i750', 'jpg'],
#     ['Pead_haricot_00103_i750', 'jpg'],
#     ['Pead_haricot_00107_i750', 'jpg'],
#     ['Pead_haricot_00110_i750', 'jpg'],
#     ['Pead_haricot_00121_i750', 'jpg'],
#     ['Pead_haricot_00124_i750', 'jpg'],
#     ['Pead_haricot_00127_i750', 'jpg'],
#     ['Pead_haricot_00147_i750', 'jpg'],
#     ['Pead_haricot_00150_i750', 'jpg'],
#     ['Pead_haricot_00153_i750', 'jpg'],
#     ['Pead_haricot_00167_i750', 'jpg'],
#     ['Pead_haricot_00171_i750', 'jpg'],
#     ['Pead_haricot_00172_i750', 'jpg'],
#     ['Pead_haricot_00215_i750', 'jpg'],
#     ['Pead_haricot_00218_i750', 'jpg'],
#     ['Pead_haricot_00221_i750', 'jpg'],
#     ['Pead_haricot_00233_i750', 'jpg'],
#     ['Pead_haricot_00236_i750', 'jpg'],
#     ['Pead_haricot_00249_i750', 'jpg'],
#     ['Pead_haricot_00273_i750', 'jpg'],
#     ['Pead_haricot_00277_i750', 'jpg'],
#     ['Pead_haricot_00294_i750', 'jpg'],
#     ['Pead_haricot_00300_i750', 'jpg'],
#     ['Pead_haricot_00310_i750', 'jpg'],
#     ['Pead_haricot_00313_i750', 'jpg'],
#     ['Pead_haricot_00319_i750', 'jpg'],
#     ['Pead_haricot_00322_i750', 'jpg'],
#     ['Pead_haricot_00332_i750', 'jpg'],
#     ['Pead_haricot_00350_i750', 'jpg'],
#     ['Pead_haricot_00356_i750', 'jpg'],
#     ['Pead_haricot_00359_i750', 'jpg'],
#     ['Pead_haricot_00362_i750', 'jpg'],
#     ['Pead_haricot_00372_i750', 'jpg'],
#     ['Pead_haricot_00403_i750', 'jpg'],
#     ['Pead_haricot_00419_i750', 'jpg'],
#     ['Pead_haricot_00422_i750', 'jpg'],
#     ['Pead_haricot_00426_i750', 'jpg'],
#     ['Pead_haricot_00437_i750', 'jpg'],
#     ['Pead_haricot_00440_i750', 'jpg'],
#     ['Pead_haricot_00443_i750', 'jpg'],
#     ['Pead_haricot_00454_i750', 'jpg'],
#     ['Pead_haricot_00457_i750', 'jpg'],
#     ['Pead_haricot_00460_i750', 'jpg'],
#     ['Pead_haricot_00466_i750', 'jpg'],
#     ['Pead_haricot_00476_i750', 'jpg'],
#     ['Pead_haricot_00479_i750', 'jpg'],
#     ['Pead_haricot_00482_i750', 'jpg'],
#     ['Pead_haricot_00485_i750', 'jpg'],
#     ['Pead_haricot_00496_i750', 'jpg'],
#     ['Pead_haricot_00503_i750', 'jpg'],
#     ['Pead_haricot_00506_i750', 'jpg'],
#     ['Pead_haricot_00516_i750', 'jpg'],
#     ['Pead_haricot_00522_i750', 'jpg'],
#     ['Pead_haricot_00525_i750', 'jpg'],
#     ['Pead_haricot_00535_i750', 'jpg'],
#     ['Pead_haricot_00538_i750', 'jpg'],
#     ['Pead_haricot_00541_i750', 'jpg'],
#     ['Pead_haricot_00544_i750', 'jpg'],
#     ['Pead_haricot_00547_i750', 'jpg'],
#     ['Pead_haricot_00585_i750', 'jpg'],
#     ['Pead_haricot_00586_i750', 'jpg'],
#     ['Pead_haricot_00589_i750', 'jpg'],
#     ['Pead_haricot_00592_i750', 'jpg'],
#     ['Pead_haricot_00602_i750', 'jpg'],
#     ['Pead_haricot_00608_i750', 'jpg'],
#     ['Pead_haricot_00622_i750', 'jpg'],
#     ['Pead_haricot_00625_i750', 'jpg'],
#     ['Pead_haricot_00644_i750', 'jpg'],
#     ['Pead_haricot_00649_i750', 'jpg'],
#     ['Pead_haricot_00652_i750', 'jpg']],
#    'Mais': [['Pead_mais_00034_i900', 'jpg'],
#     ['Pead_mais_00038_i900', 'jpg'],
#     ['Pead_mais_00046_i900', 'jpg'],
#     ['Pead_mais_00050_i900', 'jpg'],
#     ['Pead_mais_00054_i900', 'jpg'],
#     ['Pead_mais_00058_i900', 'jpg'],
#     ['Pead_mais_00062_i900', 'jpg'],
#     ['Pead_mais_00070_i900', 'jpg'],
#     ['Pead_mais_00093_i900', 'jpg'],
#     ['Pead_mais_00097_i900', 'jpg'],
#     ['Pead_mais_00101_i900', 'jpg'],
#     ['Pead_mais_00105_i900', 'jpg'],
#     ['Pead_mais_00118_i900', 'jpg'],
#     ['Pead_mais_00122_i900', 'jpg'],
#     ['Pead_mais_00126_i900', 'jpg'],
#     ['Pead_mais_00139_i900', 'jpg'],
#     ['Pead_mais_00143_i900', 'jpg'],
#     ['Pead_mais_00148_i900', 'jpg'],
#     ['Pead_mais_00152_i900', 'jpg'],
#     ['Pead_mais_00165_i900', 'jpg'],
#     ['Pead_mais_00169_i900', 'jpg'],
#     ['Pead_mais_00186_i900', 'jpg'],
#     ['Pead_mais_00194_i900', 'jpg'],
#     ['Pead_mais_00210_i900', 'jpg'],
#     ['Pead_mais_00215_i900', 'jpg'],
#     ['Pead_mais_00233_i900', 'jpg'],
#     ['Pead_mais_00249_i900', 'jpg'],
#     ['Pead_mais_00257_i900', 'jpg'],
#     ['Pead_mais_00265_i900', 'jpg'],
#     ['Pead_mais_00278_i900', 'jpg'],
#     ['Pead_mais_00283_i900', 'jpg'],
#     ['Pead_mais_00287_i900', 'jpg'],
#     ['Pead_mais_00291_i900', 'jpg'],
#     ['Pead_mais_00304_i900', 'jpg'],
#     ['Pead_mais_00312_i900', 'jpg'],
#     ['Pead_mais_00325_i900', 'jpg'],
#     ['Pead_mais_00329_i900', 'jpg'],
#     ['Pead_mais_00333_i900', 'jpg'],
#     ['Pead_mais_00355_i900', 'jpg'],
#     ['Pead_mais_00367_i900', 'jpg'],
#     ['Pead_mais_00371_i900', 'jpg'],
#     ['Pead_mais_00375_i900', 'jpg'],
#     ['Pead_mais_00407_i900', 'jpg'],
#     ['Pead_mais_00411_i900', 'jpg'],
#     ['Pead_mais_00416_i900', 'jpg'],
#     ['Pead_mais_00431_i900', 'jpg'],
#     ['Pead_mais_00443_i900', 'jpg'],
#     ['Pead_mais_00447_i900', 'jpg'],
#     ['Pead_mais_00451_i900', 'jpg'],
#     ['Pead_mais_00455_i900', 'jpg'],
#     ['Pead_mais_00471_i900', 'jpg'],
#     ['Pead_mais_00475_i900', 'jpg'],
#     ['Pead_mais_00492_i900', 'jpg'],
#     ['Pead_mais_00496_i900', 'jpg'],
#     ['Pead_mais_00500_i900', 'jpg'],
#     ['Pead_mais_00511_i900', 'jpg'],
#     ['Pead_mais_00515_i900', 'jpg'],
#     ['Pead_mais_00531_i900', 'jpg'],
#     ['Pead_mais_00535_i900', 'jpg'],
#     ['Pead_mais_00539_i900', 'jpg'],
#     ['Pead_mais_00552_i900', 'jpg'],
#     ['Pead_mais_00564_i900', 'jpg'],
#     ['Pead_mais_00580_i900', 'jpg'],
#     ['Pead_mais_00599_i900', 'jpg'],
#     ['Pead_mais_00603_i900', 'jpg'],
#     ['Pead_mais_00615_i900', 'jpg'],
#     ['Pead_mais_00631_i900', 'jpg'],
#     ['Pead_mais_00635_i900', 'jpg'],
#     ['Pead_mais_00639_i900', 'jpg'],
#     ['Pead_mais_00643_i900', 'jpg'],
#     ['Pead_mais_00647_i900', 'jpg'],
#     ['Pead_mais_00658_i900', 'jpg'],
#     ['Pead_mais_00662_i900', 'jpg'],
#     ['Pead_mais_00666_i900', 'jpg'],
#     ['Pead_mais_00683_i900', 'jpg'],
#     ['Pead_mais_00687_i900', 'jpg']]},
#   'Roseau': {'Haricot': [['Roseau_haricot_0008_false', 'png'],
#     ['Roseau_haricot_0012_false', 'png'],
#     ['Roseau_haricot_0014_false', 'png'],
#     ['Roseau_haricot_0016_false', 'png'],
#     ['Roseau_haricot_0020_false', 'png'],
#     ['Roseau_haricot_0022_false', 'png'],
#     ['Roseau_haricot_0024_false', 'png'],
#     ['Roseau_haricot_0026_false', 'png'],
#     ['Roseau_haricot_0034_false', 'png'],
#     ['Roseau_haricot_0042_false', 'png'],
#     ['Roseau_haricot_0046_false', 'png'],
#     ['Roseau_haricot_0050_false', 'png'],
#     ['Roseau_haricot_0054_false', 'png'],
#     ['Roseau_haricot_0058_false', 'png'],
#     ['Roseau_haricot_0062_false', 'png'],
#     ['Roseau_haricot_0070_false', 'png'],
#     ['Roseau_haricot_0078_false', 'png'],
#     ['Roseau_haricot_0082_false', 'png'],
#     ['Roseau_haricot_0088_false', 'png'],
#     ['Roseau_haricot_0092_false', 'png'],
#     ['Roseau_haricot_0096_false', 'png'],
#     ['Roseau_haricot_0100_false', 'png'],
#     ['Roseau_haricot_0104_false', 'png'],
#     ['Roseau_haricot_0112_false', 'png'],
#     ['Roseau_haricot_0114_false', 'png'],
#     ['Roseau_haricot_0116_false', 'png'],
#     ['Roseau_haricot_0118_false', 'png'],
#     ['Roseau_haricot_0120_false', 'png'],
#     ['Roseau_haricot_0122_false', 'png'],
#     ['Roseau_haricot_0124_false', 'png'],
#     ['Roseau_haricot_0126_false', 'png'],
#     ['Roseau_haricot_0130_false', 'png'],
#     ['Roseau_haricot_0138_false', 'png'],
#     ['Roseau_haricot_0148_false', 'png'],
#     ['Roseau_haricot_0152_false', 'png'],
#     ['Roseau_haricot_0158_false', 'png'],
#     ['Roseau_haricot_0160_false', 'png'],
#     ['Roseau_haricot_0164_false', 'png'],
#     ['Roseau_haricot_0168_false', 'png'],
#     ['Roseau_haricot_0172_false', 'png'],
#     ['Roseau_haricot_0176_false', 'png'],
#     ['Roseau_haricot_0180_false', 'png'],
#     ['Roseau_haricot_0184_false', 'png'],
#     ['Roseau_haricot_0192_false', 'png'],
#     ['Roseau_haricot_0200_false', 'png'],
#     ['Roseau_haricot_0204_false', 'png'],
#     ['Roseau_haricot_0208_false', 'png'],
#     ['Roseau_haricot_0212_false', 'png'],
#     ['Roseau_haricot_0232_false', 'png'],
#     ['Roseau_haricot_0236_false', 'png'],
#     ['Roseau_haricot_0240_false', 'png'],
#     ['Roseau_haricot_0244_false', 'png'],
#     ['Roseau_haricot_0248_false', 'png'],
#     ['Roseau_haricot_0252_false', 'png'],
#     ['Roseau_haricot_0260_false', 'png'],
#     ['Roseau_haricot_0264_false', 'png'],
#     ['Roseau_haricot_0268_false', 'png'],
#     ['Roseau_haricot_0272_false', 'png'],
#     ['Roseau_haricot_0276_false', 'png'],
#     ['Roseau_haricot_0280_false', 'png'],
#     ['Roseau_haricot_0284_false', 'png'],
#     ['Roseau_haricot_0288_false', 'png'],
#     ['Roseau_haricot_0304_false', 'png'],
#     ['Roseau_haricot_0308_false', 'png'],
#     ['Roseau_haricot_0312_false', 'png'],
#     ['Roseau_haricot_0316_false', 'png'],
#     ['Roseau_haricot_0318_false', 'png'],
#     ['Roseau_haricot_0324_false', 'png'],
#     ['Roseau_haricot_0332_false', 'png'],
#     ['Roseau_haricot_0336_false', 'png'],
#     ['Roseau_haricot_0340_false', 'png'],
#     ['Roseau_haricot_0344_false', 'png'],
#     ['Roseau_haricot_0348_false', 'png'],
#     ['Roseau_haricot_0352_false', 'png'],
#     ['Roseau_haricot_0356_false', 'png'],
#     ['Roseau_haricot_0360_false', 'png']],
#    'Mais': [['Roseau_mais_0010_false', 'png'],
#     ['Roseau_mais_0012_false', 'png'],
#     ['Roseau_mais_0018_false', 'png'],
#     ['Roseau_mais_0022_false', 'png'],
#     ['Roseau_mais_0028_false', 'png'],
#     ['Roseau_mais_0032_false', 'png'],
#     ['Roseau_mais_0034_false', 'png'],
#     ['Roseau_mais_0038_false', 'png'],
#     ['Roseau_mais_0042_false', 'png'],
#     ['Roseau_mais_0044_false', 'png'],
#     ['Roseau_mais_0052_false', 'png'],
#     ['Roseau_mais_0054_false', 'png'],
#     ['Roseau_mais_0062_false', 'png'],
#     ['Roseau_mais_0064_false', 'png'],
#     ['Roseau_mais_0070_false', 'png'],
#     ['Roseau_mais_0072_false', 'png'],
#     ['Roseau_mais_0088_false', 'png'],
#     ['Roseau_mais_0090_false', 'png'],
#     ['Roseau_mais_0092_false', 'png'],
#     ['Roseau_mais_0096_false', 'png'],
#     ['Roseau_mais_0106_false', 'png'],
#     ['Roseau_mais_0110_false', 'png'],
#     ['Roseau_mais_0118_false', 'png'],
#     ['Roseau_mais_0120_false', 'png'],
#     ['Roseau_mais_0124_false', 'png'],
#     ['Roseau_mais_0126_false', 'png'],
#     ['Roseau_mais_0132_false', 'png'],
#     ['Roseau_mais_0134_false', 'png'],
#     ['Roseau_mais_0136_false', 'png'],
#     ['Roseau_mais_0138_false', 'png'],
#     ['Roseau_mais_0140_false', 'png'],
#     ['Roseau_mais_0144_false', 'png'],
#     ['Roseau_mais_0146_false', 'png'],
#     ['Roseau_mais_0148_false', 'png'],
#     ['Roseau_mais_0150_false', 'png'],
#     ['Roseau_mais_0156_false', 'png'],
#     ['Roseau_mais_0158_false', 'png'],
#     ['Roseau_mais_0164_false', 'png'],
#     ['Roseau_mais_0166_false', 'png'],
#     ['Roseau_mais_0168_false', 'png'],
#     ['Roseau_mais_0170_false', 'png'],
#     ['Roseau_mais_0178_false', 'png'],
#     ['Roseau_mais_0180_false', 'png'],
#     ['Roseau_mais_0182_false', 'png'],
#     ['Roseau_mais_0192_false', 'png'],
#     ['Roseau_mais_0194_false', 'png'],
#     ['Roseau_mais_0206_false', 'png'],
#     ['Roseau_mais_0208_false', 'png'],
#     ['Roseau_mais_0212_false', 'png'],
#     ['Roseau_mais_0222_false', 'png'],
#     ['Roseau_mais_0228_false', 'png'],
#     ['Roseau_mais_0230_false', 'png'],
#     ['Roseau_mais_0232_false', 'png'],
#     ['Roseau_mais_0234_false', 'png'],
#     ['Roseau_mais_0236_false', 'png'],
#     ['Roseau_mais_0238_false', 'png'],
#     ['Roseau_mais_0240_false', 'png'],
#     ['Roseau_mais_0248_false', 'png'],
#     ['Roseau_mais_0254_false', 'png'],
#     ['Roseau_mais_0258_false', 'png'],
#     ['Roseau_mais_0260_false', 'png'],
#     ['Roseau_mais_0262_false', 'png'],
#     ['Roseau_mais_0264_false', 'png'],
#     ['Roseau_mais_0266_false', 'png'],
#     ['Roseau_mais_0268_false', 'png'],
#     ['Roseau_mais_0276_false', 'png'],
#     ['Roseau_mais_0278_false', 'png'],
#     ['Roseau_mais_0280_false', 'png'],
#     ['Roseau_mais_0284_false', 'png'],
#     ['Roseau_mais_0290_false', 'png'],
#     ['Roseau_mais_0294_false', 'png'],
#     ['Roseau_mais_0296_false', 'png'],
#     ['Roseau_mais_0298_false', 'png'],
#     ['Roseau_mais_0302_false', 'png'],
#     ['Roseau_mais_0304_false', 'png'],
#     ['Roseau_mais_0306_false', 'png']]},
#   'Weedelec': {'Haricot': [['Weedelec_haricot_2019-09-25T114358-6', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T
#     ['Bipbip_mais_im_10001', 'jpg'],
#     ['Bipbip_mais_im_10081', 'jpg'],
#     ['Bipbip_mais_im_10161', 'jpg'],
#     ['Bipbip_mais_im_10231', 'jpg'],
#     ['Bipbip_mais_im_10301', 'jpg'],
#     ['Bipbip_mais_im_10371', 'jpg'],
#     ['Bipbip_mais_im_10691', 'jpg'],
#     ['Bipbip_mais_im_10771', 'jpg'],
#     ['Bipbip_mais_im_10851', 'jpg'],
#     ['Bipbip_mais_im_11121', 'jpg'],
#     ['Bipbip_mais_im_11221', 'jpg']]},
#   'Pead': {'Haricot': [['Pead_haricot_00662_i750', 'jpg'],
#     ['Pead_haricot_00665_i750', 'jpg'],
#     ['Pead_haricot_00668_i750', 'jpg'],
#     ['Pead_haricot_00671_i750', 'jpg'],
#     ['Pead_haricot_00685_i750', 'jpg'],
#     ['Pead_haricot_00688_i750', 'jpg'],
#     ['Pead_haricot_00691_i750', 'jpg'],
#     ['Pead_haricot_00701_i750', 'jpg'],
#     ['Pead_haricot_00707_i750', 'jpg'],
#     ['Pead_haricot_00711_i750', 'jpg'],
#     ['Pead_haricot_00712_i750', 'jpg'],
#     ['Pead_haricot_00721_i750', 'jpg'],
#     ['Pead_haricot_00724_i750', 'jpg'],
#     ['Pead_haricot_00730_i750', 'jpg']],
#    'Mais': [['Pead_mais_00699_i900', 'jpg'],
#     ['Pead_mais_00727_i900', 'jpg'],
#     ['Pead_mais_00739_i900', 'jpg'],
#     ['Pead_mais_00748_i900', 'jpg'],
#     ['Pead_mais_00764_i900', 'jpg'],
#     ['Pead_mais_00768_i900', 'jpg'],
#     ['Pead_mais_00780_i900', 'jpg'],
#     ['Pead_mais_00788_i900', 'jpg'],
#     ['Pead_mais_00792_i900', 'jpg'],
#     ['Pead_mais_00801_i900', 'jpg'],
#     ['Pead_mais_00805_i900', 'jpg'],
#     ['Pead_mais_00809_i900', 'jpg'],
#     ['Pead_mais_00813_i900', 'jpg'],
#     ['Pead_mais_00817_i900', 'jpg']]},
#   'Roseau': {'Haricot': [['Roseau_haricot_0364_false', 'png'],
#     ['Roseau_haricot_0380_false', 'png'],
#     ['Roseau_haricot_0384_false', 'png'],
#     ['Roseau_haricot_0388_false', 'png'],
#     ['Roseau_haricot_0392_false', 'png'],
#     ['Roseau_haricot_0400_false', 'png'],
#     ['Roseau_haricot_0404_false', 'png'],
#     ['Roseau_haricot_0406_false', 'png'],
#     ['Roseau_haricot_0408_false', 'png'],
#     ['Roseau_haricot_0410_false', 'png'],
#     ['Roseau_haricot_0412_false', 'png'],
#     ['Roseau_haricot_0418_false', 'png'],
#     ['Roseau_haricot_0420_false', 'png'],
#     ['Roseau_haricot_0422_false', 'png']],
#    'Mais': [['Roseau_mais_0310_false', 'png'],
#     ['Roseau_mais_0312_false', 'png'],
#     ['Roseau_mais_0318_false', 'png'],
#     ['Roseau_mais_0320_false', 'png'],
#     ['Roseau_mais_0326_false', 'png'],
#     ['Roseau_mais_0330_false', 'png'],
#     ['Roseau_mais_0334_false', 'png'],
#     ['Roseau_mais_0336_false', 'png'],
#     ['Roseau_mais_0344_false', 'png'],
#     ['Roseau_mais_0346_false', 'png'],
#     ['Roseau_mais_0352_false', 'png'],
#     ['Roseau_mais_0356_false', 'png'],
#     ['Roseau_mais_0358_false', 'png'],
#     ['Roseau_mais_0368_false', 'png']]},
#   'Weedelec': {'Haricot': [['Weedelec_haricot_2019-09-25T115932-366', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T115952-374', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120005-379', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120013-382', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120024-386', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120036-391', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120054-398', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120105-402', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120115-406', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120125-410', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120138-415', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120202-424', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120212-428', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120235-437', 'jpg']],
#    'Mais': [['Weedelec_mais_2019-09-25T122149-380', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122157-383', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122204-386', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122212-389', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122219-392', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122232-397', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122240-400', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122250-404', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122255-406', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122308-411', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122315-414', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122323-417', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122331-420', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122339-423', 'jpg']]}}}

# %%
# ------------------------------------------
# Create the splitted dataset directory tree 
# ------------------------------------------
if SPLIT_DATASET == True:
  import shutil
  
  # Use your dataset_split.json 
  # ---------------------------
  if LOAD_FROM_JSON == True:
    import json
    f = open('/content/drive/My Drive/Challenge_2/dataset_split.json')
    split = json.load(f) 
    ! cp '/content/drive/My Drive/Challenge_2/dataset_split.json' '/content/dataset_split.json'  
  # ---------------------------


  # Create the folder for the splitted dataset
  # ------------------------------------------
  ! mkdir '/content/Development_Dataset_15'

  ! mkdir '/content/Development_Dataset_15/training'
  ! mkdir '/content/Development_Dataset_15/training/images'
  ! mkdir '/content/Development_Dataset_15/training/masks'

  ! mkdir '/content/Development_Dataset_15/validation'
  ! mkdir '/content/Development_Dataset_15/validation/images'
  ! mkdir '/content/Development_Dataset_15/validation/masks'
  # ------------------------------------------

  teams = ['Bipbip', 'Pead', 'Roseau', 'Weedelec']
  plants = ['Haricot', 'Mais']

  for t in teams:
    for p in plants:

      for img_name in split['training'][t][p]:
        
        src_path = os.path.join(cwd, 'Development_Dataset/Training/' + t + '/' + p + '/' + 'Images', img_name[0] + '.' + img_name[1])
        dst_path = os.path.join(cwd, 'Development_Dataset_15/training/images')
        shutil.move(src_path, dst_path)

        src_path = os.path.join(cwd, 'Development_Dataset/Training/' + t + '/' + p + '/' + 'Masks', img_name[0] + '.png')
        dst_path = os.path.join(cwd, 'Development_Dataset_15/training/masks')
        shutil.move(src_path, dst_path)

      for img_name in split['validation'][t][p]:
    
        src_path = os.path.join(cwd, 'Development_Dataset/Training/' + t + '/' + p + '/' + 'Images', img_name[0] + '.' + img_name[1])
        dst_path = os.path.join(cwd, 'Development_Dataset_15/validation/images')
        shutil.move(src_path, dst_path)
    
        src_path = os.path.join(cwd, 'Development_Dataset/Training/' + t + '/' + p + '/' + 'Masks', img_name[0] + '.png')
        dst_path = os.path.join(cwd, 'Development_Dataset_15/validation/masks')
        shutil.move(src_path, dst_path)
  ! ls
# Out:
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00321.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00321.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00391.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00391.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00451.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00451.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00511.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00511.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00651.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00651.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00801.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00801.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_00871.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_00871.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01021.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01021.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01091.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01091.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01271.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01271.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01451.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01451.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01541.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01541.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01631.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01631.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01731.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01731.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01821.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01821.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_01911.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_01911.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_02171.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_02171.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im_02231.jpg'
# '/content/Development_Dataset_15/training/masks/Bipbip_haricot_im_02231.png'
# '/content/Development_Dataset_15/training/images/Bipbip_haricot_im
png (deflated 34%)
# updating: Development_Dataset_15/training/masks/Pead_haricot_00150_i750.png (deflated 16%)
# updating: Development_Dataset_15/training/masks/Bipbip_mais_im_03751.png (deflated 15%)
# updating: Development_Dataset_15/training/masks/Pead_mais_00046_i900.png (deflated 23%)
# updating: Development_Dataset_15/training/masks/Pead_haricot_00585_i750.png (deflated 22%)
# updating: Development_Dataset_15/training/masks/Weedelec_mais_2019-09-25T121729-278.png (deflated 49%)
# updating: Development_Dataset_15/training/masks/Roseau_mais_0276_false.png (deflated 8%)
# updating: Development_Dataset_15/training/masks/Pead_haricot_00121_i750.png (deflated 15%)
# updating: Development_Dataset_15/training/masks/Bipbip_haricot_im_07011.png (deflated 30%)
# updating: Development_Dataset_15/training/masks/Weedelec_haricot_2019-09-25T114650-72.png (deflated 34%)
# updating: Development_Dataset_15/training/masks/Pead_haricot_00322_i750.png (deflated 14%)
# updating: Development_Dataset_15/training/masks/Bipbip_mais_im_09311.png (deflated 12%)
# updating: Development_Dataset_15/training/masks/Roseau_haricot_0116_false.png (deflated 6%)
# updating: Development_Dataset_15/training/masks/Weedelec_haricot_2019-09-25T115028-156.png (deflated 22%)
# updating: Development_Dataset_15/training/masks/Bipbip_mais_im_01511.png (deflated 14%)
# updating: Development_Dataset_15/training/masks/Roseau_mais_0012_false.png (deflated 14%)
# updating: Development_Dataset_15/training/masks/Bipbip_haricot_im_06901.png (deflated 26%)
# updating: Development_Dataset_15/training/masks/Weedelec_mais_2019-09-25T120634-24.png (deflated 59%)
# updating: Development_Dataset_15/training/masks/Pead_mais_00599_i900.png (deflated 9%)
# updating: Development_Dataset_15/training/masks/Bipbip_haricot_im_04401.png (deflated 19%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0106_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00034_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_06691.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_06901.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00531_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115028-156.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T121937-328.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00121_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0192_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00313_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_05281.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_05381.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_02781.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0332_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T120917-87.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T121531-232.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T121846-308.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0134_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00150_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_03291.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0212_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_09311.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115754-328.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115054-166.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00107_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00122_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T114934-135.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0058_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0200_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115228-203.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_04561.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00506_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0268_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0264_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00322_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115549-280.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00539_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_05361.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_07761.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T120738-49.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T120634-24.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0254_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0034_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0276_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0252_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115446-256.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00152_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T114618-60.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0012_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_04911.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0238_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_07911.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0324_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115533-274.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00625_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T121729-278.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_04401.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_06101.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0262_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00356_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00143_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_02351.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115502-262.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T120700-34.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0146_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_05351.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_01511.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00329_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00325_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0038_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T114650-72.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_06151.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00016_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0232_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_07011.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00422_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_03411.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00147_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_mais_im_03751.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T114736-90.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00599_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00089_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00355_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00058_i900.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0276_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_mais_2019-09-25T120802-58.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115412-243.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Bipbip_haricot_im_03611.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00585_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_haricot_0116_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Weedelec_haricot_2019-09-25T115541-277.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Roseau_mais_0012_false.png (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_haricot_00535_i750.jpg (deflated 0%)
# updating: Development_Dataset_15/training/images/Pead_mais_00046_i900.jpg (deflated 0%)

# %% [markdown]
# ### Cells executed if: SPLIT_DATASET = False

# %%
# --------------------------------------------------------------------------------
# Unzip the json file with the split used and the splitted dataset from your drive
# --------------------------------------------------------------------------------
if SPLIT_DATASET == False:
  # Get dataset_split.json
  ! cp '/content/drive/My Drive/Challenge_2/dataset_split.json' '/content/dataset_split.json' 
  # Get the splitted dataset
  ! unzip '/content/drive/My Drive/Challenge_2/Development_Dataset_15.zip'

# %%
import json

subset_file = os.path.join('/content', 'dataset_split.json')
with open(subset_file, 'r') as f:
  data = json.load(f)

data
# Out:
# {'training': {'Bipbip': {'Haricot': [['Bipbip_haricot_im_00321', 'jpg'],
#     ['Bipbip_haricot_im_00391', 'jpg'],
#     ['Bipbip_haricot_im_00451', 'jpg'],
#     ['Bipbip_haricot_im_00511', 'jpg'],
#     ['Bipbip_haricot_im_00651', 'jpg'],
#     ['Bipbip_haricot_im_00801', 'jpg'],
#     ['Bipbip_haricot_im_00871', 'jpg'],
#     ['Bipbip_haricot_im_01021', 'jpg'],
#     ['Bipbip_haricot_im_01091', 'jpg'],
#     ['Bipbip_haricot_im_01271', 'jpg'],
#     ['Bipbip_haricot_im_01451', 'jpg'],
#     ['Bipbip_haricot_im_01541', 'jpg'],
#     ['Bipbip_haricot_im_01631', 'jpg'],
#     ['Bipbip_haricot_im_01731', 'jpg'],
#     ['Bipbip_haricot_im_01821', 'jpg'],
#     ['Bipbip_haricot_im_01911', 'jpg'],
#     ['Bipbip_haricot_im_02171', 'jpg'],
#     ['Bipbip_haricot_im_02231', 'jpg'],
#     ['Bipbip_haricot_im_02301', 'jpg'],
#     ['Bipbip_haricot_im_02351', 'jpg'],
#     ['Bipbip_haricot_im_02531', 'jpg'],
#     ['Bipbip_haricot_im_02651', 'jpg'],
#     ['Bipbip_haricot_im_03041', 'jpg'],
#     ['Bipbip_haricot_im_03111', 'jpg'],
#     ['Bipbip_haricot_im_03231', 'jpg'],
#     ['Bipbip_haricot_im_03281', 'jpg'],
#     ['Bipbip_haricot_im_03291', 'jpg'],
#     ['Bipbip_haricot_im_03411', 'jpg'],
#     ['Bipbip_haricot_im_03461', 'jpg'],
#     ['Bipbip_haricot_im_03481', 'jpg'],
#     ['Bipbip_haricot_im_03531', 'jpg'],
#     ['Bipbip_haricot_im_03571', 'jpg'],
#     ['Bipbip_haricot_im_03611', 'jpg'],
#     ['Bipbip_haricot_im_03751', 'jpg'],
#     ['Bipbip_haricot_im_03841', 'jpg'],
#     ['Bipbip_haricot_im_03961', 'jpg'],
#     ['Bipbip_haricot_im_04031', 'jpg'],
#     ['Bipbip_haricot_im_04301', 'jpg'],
#     ['Bipbip_haricot_im_04401', 'jpg'],
#     ['Bipbip_haricot_im_04541', 'jpg'],
#     ['Bipbip_haricot_im_04591', 'jpg'],
#     ['Bipbip_haricot_im_04741', 'jpg'],
#     ['Bipbip_haricot_im_04791', 'jpg'],
#     ['Bipbip_haricot_im_04851', 'jpg'],
#     ['Bipbip_haricot_im_04991', 'jpg'],
#     ['Bipbip_haricot_im_05041', 'jpg'],
#     ['Bipbip_haricot_im_05111', 'jpg'],
#     ['Bipbip_haricot_im_05141', 'jpg'],
#     ['Bipbip_haricot_im_05231', 'jpg'],
#     ['Bipbip_haricot_im_05301', 'jpg'],
#     ['Bipbip_haricot_im_05351', 'jpg'],
#     ['Bipbip_haricot_im_05361', 'jpg'],
#     ['Bipbip_haricot_im_05411', 'jpg'],
#     ['Bipbip_haricot_im_05421', 'jpg'],
#     ['Bipbip_haricot_im_05461', 'jpg'],
#     ['Bipbip_haricot_im_05481', 'jpg'],
#     ['Bipbip_haricot_im_05531', 'jpg'],
#     ['Bipbip_haricot_im_05571', 'jpg'],
#     ['Bipbip_haricot_im_05741', 'jpg'],
#     ['Bipbip_haricot_im_05911', 'jpg'],
#     ['Bipbip_haricot_im_05991', 'jpg'],
#     ['Bipbip_haricot_im_06041', 'jpg'],
#     ['Bipbip_haricot_im_06101', 'jpg'],
#     ['Bipbip_haricot_im_06151', 'jpg'],
#     ['Bipbip_haricot_im_06241', 'jpg'],
#     ['Bipbip_haricot_im_06341', 'jpg'],
#     ['Bipbip_haricot_im_06401', 'jpg'],
#     ['Bipbip_haricot_im_06481', 'jpg'],
#     ['Bipbip_haricot_im_06531', 'jpg'],
#     ['Bipbip_haricot_im_06641', 'jpg'],
#     ['Bipbip_haricot_im_06691', 'jpg'],
#     ['Bipbip_haricot_im_06801', 'jpg'],
#     ['Bipbip_haricot_im_06851', 'jpg'],
#     ['Bipbip_haricot_im_06901', 'jpg'],
#     ['Bipbip_haricot_im_06941', 'jpg'],
#     ['Bipbip_haricot_im_07011', 'jpg']],
#    'Mais': [['Bipbip_mais_im_01391', 'jpg'],
#     ['Bipbip_mais_im_01461', 'jpg'],
#     ['Bipbip_mais_im_01511', 'jpg'],
#     ['Bipbip_mais_im_01561', 'jpg'],
#     ['Bipbip_mais_im_01601', 'jpg'],
#     ['Bipbip_mais_im_01681', 'jpg'],
#     ['Bipbip_mais_im_01751', 'jpg'],
#     ['Bipbip_mais_im_01871', 'jpg'],
#     ['Bipbip_mais_im_02151', 'jpg'],
#     ['Bipbip_mais_im_02281', 'jpg'],
#     ['Bipbip_mais_im_02371', 'jpg'],
#     ['Bipbip_mais_im_02411', 'jpg'],
#     ['Bipbip_mais_im_02461', 'jpg'],
#     ['Bipbip_mais_im_02511', 'jpg'],
#     ['Bipbip_mais_im_02691', 'jpg'],
#     ['Bipbip_mais_im_02731', 'jpg'],
#     ['Bipbip_mais_im_02781', 'jpg'],
#     ['Bipbip_mais_im_02891', 'jpg'],
#     ['Bipbip_mais_im_02941', 'jpg'],
#     ['Bipbip_mais_im_03121', 'jpg'],
#     ['Bipbip_mais_im_03181', 'jpg'],
#     ['Bipbip_mais_im_03231', 'jpg'],
#     ['Bipbip_mais_im_03291', 'jpg'],
#     ['Bipbip_mais_im_03391', 'jpg'],
#     ['Bipbip_mais_im_03511', 'jpg'],
#     ['Bipbip_mais_im_03581', 'jpg'],
#     ['Bipbip_mais_im_03691', 'jpg'],
#     ['Bipbip_mais_im_03751', 'jpg'],
#     ['Bipbip_mais_im_03811', 'jpg'],
#     ['Bipbip_mais_im_03871', 'jpg'],
#     ['Bipbip_mais_im_03921', 'jpg'],
#     ['Bipbip_mais_im_04031', 'jpg'],
#     ['Bipbip_mais_im_04501', 'jpg'],
#     ['Bipbip_mais_im_04561', 'jpg'],
#     ['Bipbip_mais_im_04621', 'jpg'],
#     ['Bipbip_mais_im_04671', 'jpg'],
#     ['Bipbip_mais_im_04781', 'jpg'],
#     ['Bipbip_mais_im_04911', 'jpg'],
#     ['Bipbip_mais_im_05031', 'jpg'],
#     ['Bipbip_mais_im_05221', 'jpg'],
#     ['Bipbip_mais_im_05281', 'jpg'],
#     ['Bipbip_mais_im_05381', 'jpg'],
#     ['Bipbip_mais_im_05451', 'jpg'],
#     ['Bipbip_mais_im_05691', 'jpg'],
#     ['Bipbip_mais_im_05801', 'jpg'],
#     ['Bipbip_mais_im_05871', 'jpg'],
#     ['Bipbip_mais_im_06071', 'jpg'],
#     ['Bipbip_mais_im_06141', 'jpg'],
#     ['Bipbip_mais_im_06541', 'jpg'],
#     ['Bipbip_mais_im_06691', 'jpg'],
#     ['Bipbip_mais_im_06961', 'jpg'],
#     ['Bipbip_mais_im_07041', 'jpg'],
#     ['Bipbip_mais_im_07181', 'jpg'],
#     ['Bipbip_mais_im_07271', 'jpg'],
#     ['Bipbip_mais_im_07351', 'jpg'],
#     ['Bipbip_mais_im_07451', 'jpg'],
#     ['Bipbip_mais_im_07531', 'jpg'],
#     ['Bipbip_mais_im_07761', 'jpg'],
#     ['Bipbip_mais_im_07831', 'jpg'],
#     ['Bipbip_mais_im_07911', 'jpg'],
#     ['Bipbip_mais_im_07991', 'jpg'],
#     ['Bipbip_mais_im_08061', 'jpg'],
#     ['Bipbip_mais_im_08121', 'jpg'],
#     ['Bipbip_mais_im_08261', 'jpg'],
#     ['Bipbip_mais_im_08321', 'jpg'],
#     ['Bipbip_mais_im_08381', 'jpg'],
#     ['Bipbip_mais_im_08441', 'jpg'],
#     ['Bipbip_mais_im_08511', 'jpg'],
#     ['Bipbip_mais_im_08581', 'jpg'],
#     ['Bipbip_mais_im_08661', 'jpg'],
#     ['Bipbip_mais_im_08731', 'jpg'],
#     ['Bipbip_mais_im_08811', 'jpg'],
#     ['Bipbip_mais_im_09231', 'jpg'],
#     ['Bipbip_mais_im_09311', 'jpg'],
#     ['Bipbip_mais_im_09501', 'jpg'],
#     ['Bipbip_mais_im_09641', 'jpg']]},
#   'Pead': {'Haricot': [['Pead_haricot_00006_i750', 'jpg'],
#     ['Pead_haricot_00016_i750', 'jpg'],
#     ['Pead_haricot_00047_i750', 'jpg'],
#     ['Pead_haricot_00066_i750', 'jpg'],
#     ['Pead_haricot_00069_i750', 'jpg'],
#     ['Pead_haricot_00079_i750', 'jpg'],
#     ['Pead_haricot_00089_i750', 'jpg'],
#     ['Pead_haricot_00103_i750', 'jpg'],
#     ['Pead_haricot_00107_i750', 'jpg'],
#     ['Pead_haricot_00110_i750', 'jpg'],
#     ['Pead_haricot_00121_i750', 'jpg'],
#     ['Pead_haricot_00124_i750', 'jpg'],
#     ['Pead_haricot_00127_i750', 'jpg'],
#     ['Pead_haricot_00147_i750', 'jpg'],
#     ['Pead_haricot_00150_i750', 'jpg'],
#     ['Pead_haricot_00153_i750', 'jpg'],
#     ['Pead_haricot_00167_i750', 'jpg'],
#     ['Pead_haricot_00171_i750', 'jpg'],
#     ['Pead_haricot_00172_i750', 'jpg'],
#     ['Pead_haricot_00215_i750', 'jpg'],
#     ['Pead_haricot_00218_i750', 'jpg'],
#     ['Pead_haricot_00221_i750', 'jpg'],
#     ['Pead_haricot_00233_i750', 'jpg'],
#     ['Pead_haricot_00236_i750', 'jpg'],
#     ['Pead_haricot_00249_i750', 'jpg'],
#     ['Pead_haricot_00273_i750', 'jpg'],
#     ['Pead_haricot_00277_i750', 'jpg'],
#     ['Pead_haricot_00294_i750', 'jpg'],
#     ['Pead_haricot_00300_i750', 'jpg'],
#     ['Pead_haricot_00310_i750', 'jpg'],
#     ['Pead_haricot_00313_i750', 'jpg'],
#     ['Pead_haricot_00319_i750', 'jpg'],
#     ['Pead_haricot_00322_i750', 'jpg'],
#     ['Pead_haricot_00332_i750', 'jpg'],
#     ['Pead_haricot_00350_i750', 'jpg'],
#     ['Pead_haricot_00356_i750', 'jpg'],
#     ['Pead_haricot_00359_i750', 'jpg'],
#     ['Pead_haricot_00362_i750', 'jpg'],
#     ['Pead_haricot_00372_i750', 'jpg'],
#     ['Pead_haricot_00403_i750', 'jpg'],
#     ['Pead_haricot_00419_i750', 'jpg'],
#     ['Pead_haricot_00422_i750', 'jpg'],
#     ['Pead_haricot_00426_i750', 'jpg'],
#     ['Pead_haricot_00437_i750', 'jpg'],
#     ['Pead_haricot_00440_i750', 'jpg'],
#     ['Pead_haricot_00443_i750', 'jpg'],
#     ['Pead_haricot_00454_i750', 'jpg'],
#     ['Pead_haricot_00457_i750', 'jpg'],
#     ['Pead_haricot_00460_i750', 'jpg'],
#     ['Pead_haricot_00466_i750', 'jpg'],
#     ['Pead_haricot_00476_i750', 'jpg'],
#     ['Pead_haricot_00479_i750', 'jpg'],
#     ['Pead_haricot_00482_i750', 'jpg'],
#     ['Pead_haricot_00485_i750', 'jpg'],
#     ['Pead_haricot_00496_i750', 'jpg'],
#     ['Pead_haricot_00503_i750', 'jpg'],
#     ['Pead_haricot_00506_i750', 'jpg'],
#     ['Pead_haricot_00516_i750', 'jpg'],
#     ['Pead_haricot_00522_i750', 'jpg'],
#     ['Pead_haricot_00525_i750', 'jpg'],
#     ['Pead_haricot_00535_i750', 'jpg'],
#     ['Pead_haricot_00538_i750', 'jpg'],
#     ['Pead_haricot_00541_i750', 'jpg'],
#     ['Pead_haricot_00544_i750', 'jpg'],
#     ['Pead_haricot_00547_i750', 'jpg'],
#     ['Pead_haricot_00585_i750', 'jpg'],
#     ['Pead_haricot_00586_i750', 'jpg'],
#     ['Pead_haricot_00589_i750', 'jpg'],
#     ['Pead_haricot_00592_i750', 'jpg'],
#     ['Pead_haricot_00602_i750', 'jpg'],
#     ['Pead_haricot_00608_i750', 'jpg'],
#     ['Pead_haricot_00622_i750', 'jpg'],
#     ['Pead_haricot_00625_i750', 'jpg'],
#     ['Pead_haricot_00644_i750', 'jpg'],
#     ['Pead_haricot_00649_i750', 'jpg'],
#     ['Pead_haricot_00652_i750', 'jpg']],
#    'Mais': [['Pead_mais_00034_i900', 'jpg'],
#     ['Pead_mais_00038_i900', 'jpg'],
#     ['Pead_mais_00046_i900', 'jpg'],
#     ['Pead_mais_00050_i900', 'jpg'],
#     ['Pead_mais_00054_i900', 'jpg'],
#     ['Pead_mais_00058_i900', 'jpg'],
#     ['Pead_mais_00062_i900', 'jpg'],
#     ['Pead_mais_00070_i900', 'jpg'],
#     ['Pead_mais_00093_i900', 'jpg'],
#     ['Pead_mais_00097_i900', 'jpg'],
#     ['Pead_mais_00101_i900', 'jpg'],
#     ['Pead_mais_00105_i900', 'jpg'],
#     ['Pead_mais_00118_i900', 'jpg'],
#     ['Pead_mais_00122_i900', 'jpg'],
#     ['Pead_mais_00126_i900', 'jpg'],
#     ['Pead_mais_00139_i900', 'jpg'],
#     ['Pead_mais_00143_i900', 'jpg'],
#     ['Pead_mais_00148_i900', 'jpg'],
#     ['Pead_mais_00152_i900', 'jpg'],
#     ['Pead_mais_00165_i900', 'jpg'],
#     ['Pead_mais_00169_i900', 'jpg'],
#     ['Pead_mais_00186_i900', 'jpg'],
#     ['Pead_mais_00194_i900', 'jpg'],
#     ['Pead_mais_00210_i900', 'jpg'],
#     ['Pead_mais_00215_i900', 'jpg'],
#     ['Pead_mais_00233_i900', 'jpg'],
#     ['Pead_mais_00249_i900', 'jpg'],
#     ['Pead_mais_00257_i900', 'jpg'],
#     ['Pead_mais_00265_i900', 'jpg'],
#     ['Pead_mais_00278_i900', 'jpg'],
#     ['Pead_mais_00283_i900', 'jpg'],
#     ['Pead_mais_00287_i900', 'jpg'],
#     ['Pead_mais_00291_i900', 'jpg'],
#     ['Pead_mais_00304_i900', 'jpg'],
#     ['Pead_mais_00312_i900', 'jpg'],
#     ['Pead_mais_00325_i900', 'jpg'],
#     ['Pead_mais_00329_i900', 'jpg'],
#     ['Pead_mais_00333_i900', 'jpg'],
#     ['Pead_mais_00355_i900', 'jpg'],
#     ['Pead_mais_00367_i900', 'jpg'],
#     ['Pead_mais_00371_i900', 'jpg'],
#     ['Pead_mais_00375_i900', 'jpg'],
#     ['Pead_mais_00407_i900', 'jpg'],
#     ['Pead_mais_00411_i900', 'jpg'],
#     ['Pead_mais_00416_i900', 'jpg'],
#     ['Pead_mais_00431_i900', 'jpg'],
#     ['Pead_mais_00443_i900', 'jpg'],
#     ['Pead_mais_00447_i900', 'jpg'],
#     ['Pead_mais_00451_i900', 'jpg'],
#     ['Pead_mais_00455_i900', 'jpg'],
#     ['Pead_mais_00471_i900', 'jpg'],
#     ['Pead_mais_00475_i900', 'jpg'],
#     ['Pead_mais_00492_i900', 'jpg'],
#     ['Pead_mais_00496_i900', 'jpg'],
#     ['Pead_mais_00500_i900', 'jpg'],
#     ['Pead_mais_00511_i900', 'jpg'],
#     ['Pead_mais_00515_i900', 'jpg'],
#     ['Pead_mais_00531_i900', 'jpg'],
#     ['Pead_mais_00535_i900', 'jpg'],
#     ['Pead_mais_00539_i900', 'jpg'],
#     ['Pead_mais_00552_i900', 'jpg'],
#     ['Pead_mais_00564_i900', 'jpg'],
#     ['Pead_mais_00580_i900', 'jpg'],
#     ['Pead_mais_00599_i900', 'jpg'],
#     ['Pead_mais_00603_i900', 'jpg'],
#     ['Pead_mais_00615_i900', 'jpg'],
#     ['Pead_mais_00631_i900', 'jpg'],
#     ['Pead_mais_00635_i900', 'jpg'],
#     ['Pead_mais_00639_i900', 'jpg'],
#     ['Pead_mais_00643_i900', 'jpg'],
#     ['Pead_mais_00647_i900', 'jpg'],
#     ['Pead_mais_00658_i900', 'jpg'],
#     ['Pead_mais_00662_i900', 'jpg'],
#     ['Pead_mais_00666_i900', 'jpg'],
#     ['Pead_mais_00683_i900', 'jpg'],
#     ['Pead_mais_00687_i900', 'jpg']]},
#   'Roseau': {'Haricot': [['Roseau_haricot_0008_false', 'png'],
#     ['Roseau_haricot_0012_false', 'png'],
#     ['Roseau_haricot_0014_false', 'png'],
#     ['Roseau_haricot_0016_false', 'png'],
#     ['Roseau_haricot_0020_false', 'png'],
#     ['Roseau_haricot_0022_false', 'png'],
#     ['Roseau_haricot_0024_false', 'png'],
#     ['Roseau_haricot_0026_false', 'png'],
#     ['Roseau_haricot_0034_false', 'png'],
#     ['Roseau_haricot_0042_false', 'png'],
#     ['Roseau_haricot_0046_false', 'png'],
#     ['Roseau_haricot_0050_false', 'png'],
#     ['Roseau_haricot_0054_false', 'png'],
#     ['Roseau_haricot_0058_false', 'png'],
#     ['Roseau_haricot_0062_false', 'png'],
#     ['Roseau_haricot_0070_false', 'png'],
#     ['Roseau_haricot_0078_false', 'png'],
#     ['Roseau_haricot_0082_false', 'png'],
#     ['Roseau_haricot_0088_false', 'png'],
#     ['Roseau_haricot_0092_false', 'png'],
#     ['Roseau_haricot_0096_false', 'png'],
#     ['Roseau_haricot_0100_false', 'png'],
#     ['Roseau_haricot_0104_false', 'png'],
#     ['Roseau_haricot_0112_false', 'png'],
#     ['Roseau_haricot_0114_false', 'png'],
#     ['Roseau_haricot_0116_false', 'png'],
#     ['Roseau_haricot_0118_false', 'png'],
#     ['Roseau_haricot_0120_false', 'png'],
#     ['Roseau_haricot_0122_false', 'png'],
#     ['Roseau_haricot_0124_false', 'png'],
#     ['Roseau_haricot_0126_false', 'png'],
#     ['Roseau_haricot_0130_false', 'png'],
#     ['Roseau_haricot_0138_false', 'png'],
#     ['Roseau_haricot_0148_false', 'png'],
#     ['Roseau_haricot_0152_false', 'png'],
#     ['Roseau_haricot_0158_false', 'png'],
#     ['Roseau_haricot_0160_false', 'png'],
#     ['Roseau_haricot_0164_false', 'png'],
#     ['Roseau_haricot_0168_false', 'png'],
#     ['Roseau_haricot_0172_false', 'png'],
#     ['Roseau_haricot_0176_false', 'png'],
#     ['Roseau_haricot_0180_false', 'png'],
#     ['Roseau_haricot_0184_false', 'png'],
#     ['Roseau_haricot_0192_false', 'png'],
#     ['Roseau_haricot_0200_false', 'png'],
#     ['Roseau_haricot_0204_false', 'png'],
#     ['Roseau_haricot_0208_false', 'png'],
#     ['Roseau_haricot_0212_false', 'png'],
#     ['Roseau_haricot_0232_false', 'png'],
#     ['Roseau_haricot_0236_false', 'png'],
#     ['Roseau_haricot_0240_false', 'png'],
#     ['Roseau_haricot_0244_false', 'png'],
#     ['Roseau_haricot_0248_false', 'png'],
#     ['Roseau_haricot_0252_false', 'png'],
#     ['Roseau_haricot_0260_false', 'png'],
#     ['Roseau_haricot_0264_false', 'png'],
#     ['Roseau_haricot_0268_false', 'png'],
#     ['Roseau_haricot_0272_false', 'png'],
#     ['Roseau_haricot_0276_false', 'png'],
#     ['Roseau_haricot_0280_false', 'png'],
#     ['Roseau_haricot_0284_false', 'png'],
#     ['Roseau_haricot_0288_false', 'png'],
#     ['Roseau_haricot_0304_false', 'png'],
#     ['Roseau_haricot_0308_false', 'png'],
#     ['Roseau_haricot_0312_false', 'png'],
#     ['Roseau_haricot_0316_false', 'png'],
#     ['Roseau_haricot_0318_false', 'png'],
#     ['Roseau_haricot_0324_false', 'png'],
#     ['Roseau_haricot_0332_false', 'png'],
#     ['Roseau_haricot_0336_false', 'png'],
#     ['Roseau_haricot_0340_false', 'png'],
#     ['Roseau_haricot_0344_false', 'png'],
#     ['Roseau_haricot_0348_false', 'png'],
#     ['Roseau_haricot_0352_false', 'png'],
#     ['Roseau_haricot_0356_false', 'png'],
#     ['Roseau_haricot_0360_false', 'png']],
#    'Mais': [['Roseau_mais_0010_false', 'png'],
#     ['Roseau_mais_0012_false', 'png'],
#     ['Roseau_mais_0018_false', 'png'],
#     ['Roseau_mais_0022_false', 'png'],
#     ['Roseau_mais_0028_false', 'png'],
#     ['Roseau_mais_0032_false', 'png'],
#     ['Roseau_mais_0034_false', 'png'],
#     ['Roseau_mais_0038_false', 'png'],
#     ['Roseau_mais_0042_false', 'png'],
#     ['Roseau_mais_0044_false', 'png'],
#     ['Roseau_mais_0052_false', 'png'],
#     ['Roseau_mais_0054_false', 'png'],
#     ['Roseau_mais_0062_false', 'png'],
#     ['Roseau_mais_0064_false', 'png'],
#     ['Roseau_mais_0070_false', 'png'],
#     ['Roseau_mais_0072_false', 'png'],
#     ['Roseau_mais_0088_false', 'png'],
#     ['Roseau_mais_0090_false', 'png'],
#     ['Roseau_mais_0092_false', 'png'],
#     ['Roseau_mais_0096_false', 'png'],
#     ['Roseau_mais_0106_false', 'png'],
#     ['Roseau_mais_0110_false', 'png'],
#     ['Roseau_mais_0118_false', 'png'],
#     ['Roseau_mais_0120_false', 'png'],
#     ['Roseau_mais_0124_false', 'png'],
#     ['Roseau_mais_0126_false', 'png'],
#     ['Roseau_mais_0132_false', 'png'],
#     ['Roseau_mais_0134_false', 'png'],
#     ['Roseau_mais_0136_false', 'png'],
#     ['Roseau_mais_0138_false', 'png'],
#     ['Roseau_mais_0140_false', 'png'],
#     ['Roseau_mais_0144_false', 'png'],
#     ['Roseau_mais_0146_false', 'png'],
#     ['Roseau_mais_0148_false', 'png'],
#     ['Roseau_mais_0150_false', 'png'],
#     ['Roseau_mais_0156_false', 'png'],
#     ['Roseau_mais_0158_false', 'png'],
#     ['Roseau_mais_0164_false', 'png'],
#     ['Roseau_mais_0166_false', 'png'],
#     ['Roseau_mais_0168_false', 'png'],
#     ['Roseau_mais_0170_false', 'png'],
#     ['Roseau_mais_0178_false', 'png'],
#     ['Roseau_mais_0180_false', 'png'],
#     ['Roseau_mais_0182_false', 'png'],
#     ['Roseau_mais_0192_false', 'png'],
#     ['Roseau_mais_0194_false', 'png'],
#     ['Roseau_mais_0206_false', 'png'],
#     ['Roseau_mais_0208_false', 'png'],
#     ['Roseau_mais_0212_false', 'png'],
#     ['Roseau_mais_0222_false', 'png'],
#     ['Roseau_mais_0228_false', 'png'],
 'jpg'],
#     ['Weedelec_mais_2019-09-25T122005-339', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122016-343', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122023-346', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122033-350', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122041-353', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122054-358', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122059-360', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122137-375', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122144-378', 'jpg']]}},
#  'validation': {'Bipbip': {'Haricot': [['Bipbip_haricot_im_07071', 'jpg'],
#     ['Bipbip_haricot_im_07131', 'jpg'],
#     ['Bipbip_haricot_im_07371', 'jpg'],
#     ['Bipbip_haricot_im_07481', 'jpg'],
#     ['Bipbip_haricot_im_07531', 'jpg'],
#     ['Bipbip_haricot_im_07591', 'jpg'],
#     ['Bipbip_haricot_im_07701', 'jpg'],
#     ['Bipbip_haricot_im_07781', 'jpg'],
#     ['Bipbip_haricot_im_07861', 'jpg'],
#     ['Bipbip_haricot_im_07941', 'jpg'],
#     ['Bipbip_haricot_im_08071', 'jpg'],
#     ['Bipbip_haricot_im_08141', 'jpg'],
#     ['Bipbip_haricot_im_08221', 'jpg'],
#     ['Bipbip_haricot_im_08371', 'jpg']],
#    'Mais': [['Bipbip_mais_im_09711', 'jpg'],
#     ['Bipbip_mais_im_09841', 'jpg'],
#     ['Bipbip_mais_im_09921', 'jpg'],
#     ['Bipbip_mais_im_10001', 'jpg'],
#     ['Bipbip_mais_im_10081', 'jpg'],
#     ['Bipbip_mais_im_10161', 'jpg'],
#     ['Bipbip_mais_im_10231', 'jpg'],
#     ['Bipbip_mais_im_10301', 'jpg'],
#     ['Bipbip_mais_im_10371', 'jpg'],
#     ['Bipbip_mais_im_10691', 'jpg'],
#     ['Bipbip_mais_im_10771', 'jpg'],
#     ['Bipbip_mais_im_10851', 'jpg'],
#     ['Bipbip_mais_im_11121', 'jpg'],
#     ['Bipbip_mais_im_11221', 'jpg']]},
#   'Pead': {'Haricot': [['Pead_haricot_00662_i750', 'jpg'],
#     ['Pead_haricot_00665_i750', 'jpg'],
#     ['Pead_haricot_00668_i750', 'jpg'],
#     ['Pead_haricot_00671_i750', 'jpg'],
#     ['Pead_haricot_00685_i750', 'jpg'],
#     ['Pead_haricot_00688_i750', 'jpg'],
#     ['Pead_haricot_00691_i750', 'jpg'],
#     ['Pead_haricot_00701_i750', 'jpg'],
#     ['Pead_haricot_00707_i750', 'jpg'],
#     ['Pead_haricot_00711_i750', 'jpg'],
#     ['Pead_haricot_00712_i750', 'jpg'],
#     ['Pead_haricot_00721_i750', 'jpg'],
#     ['Pead_haricot_00724_i750', 'jpg'],
#     ['Pead_haricot_00730_i750', 'jpg']],
#    'Mais': [['Pead_mais_00699_i900', 'jpg'],
#     ['Pead_mais_00727_i900', 'jpg'],
#     ['Pead_mais_00739_i900', 'jpg'],
#     ['Pead_mais_00748_i900', 'jpg'],
#     ['Pead_mais_00764_i900', 'jpg'],
#     ['Pead_mais_00768_i900', 'jpg'],
#     ['Pead_mais_00780_i900', 'jpg'],
#     ['Pead_mais_00788_i900', 'jpg'],
#     ['Pead_mais_00792_i900', 'jpg'],
#     ['Pead_mais_00801_i900', 'jpg'],
#     ['Pead_mais_00805_i900', 'jpg'],
#     ['Pead_mais_00809_i900', 'jpg'],
#     ['Pead_mais_00813_i900', 'jpg'],
#     ['Pead_mais_00817_i900', 'jpg']]},
#   'Roseau': {'Haricot': [['Roseau_haricot_0364_false', 'png'],
#     ['Roseau_haricot_0380_false', 'png'],
#     ['Roseau_haricot_0384_false', 'png'],
#     ['Roseau_haricot_0388_false', 'png'],
#     ['Roseau_haricot_0392_false', 'png'],
#     ['Roseau_haricot_0400_false', 'png'],
#     ['Roseau_haricot_0404_false', 'png'],
#     ['Roseau_haricot_0406_false', 'png'],
#     ['Roseau_haricot_0408_false', 'png'],
#     ['Roseau_haricot_0410_false', 'png'],
#     ['Roseau_haricot_0412_false', 'png'],
#     ['Roseau_haricot_0418_false', 'png'],
#     ['Roseau_haricot_0420_false', 'png'],
#     ['Roseau_haricot_0422_false', 'png']],
#    'Mais': [['Roseau_mais_0310_false', 'png'],
#     ['Roseau_mais_0312_false', 'png'],
#     ['Roseau_mais_0318_false', 'png'],
#     ['Roseau_mais_0320_false', 'png'],
#     ['Roseau_mais_0326_false', 'png'],
#     ['Roseau_mais_0330_false', 'png'],
#     ['Roseau_mais_0334_false', 'png'],
#     ['Roseau_mais_0336_false', 'png'],
#     ['Roseau_mais_0344_false', 'png'],
#     ['Roseau_mais_0346_false', 'png'],
#     ['Roseau_mais_0352_false', 'png'],
#     ['Roseau_mais_0356_false', 'png'],
#     ['Roseau_mais_0358_false', 'png'],
#     ['Roseau_mais_0368_false', 'png']]},
#   'Weedelec': {'Haricot': [['Weedelec_haricot_2019-09-25T115932-366', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T115952-374', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120005-379', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120013-382', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120024-386', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120036-391', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120054-398', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120105-402', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120115-406', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120125-410', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120138-415', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120202-424', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120212-428', 'jpg'],
#     ['Weedelec_haricot_2019-09-25T120235-437', 'jpg']],
#    'Mais': [['Weedelec_mais_2019-09-25T122149-380', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122157-383', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122204-386', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122212-389', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122219-392', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122232-397', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122240-400', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122250-404', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122255-406', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122308-411', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122315-414', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122323-417', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122331-420', 'jpg'],
#     ['Weedelec_mais_2019-09-25T122339-423', 'jpg']]}}}

# %% [markdown]
# # Dataset Setup

# %%
# --------------------------------------------------------------------------------------
# Create the training and validation ImageDataGenerator objects for from scratch network
# --------------------------------------------------------------------------------------
def data_generator(apply_data_augmentation):

  from tensorflow.keras.preprocessing.image import ImageDataGenerator

  apply_data_augmentation = True

  # Create training ImageDataGenerator object
  # We need two different generators for images and corresponding masks
  if apply_data_augmentation:
    img_data_gen = ImageDataGenerator(rotation_range=10,
                                      width_shift_range=10,
                                      height_shift_range=10,
                                      zoom_range=0.3,
                                      horizontal_flip=True,
                                      vertical_flip=True,
                                      fill_mode='reflect'
                                      )

    mask_data_gen = ImageDataGenerator(rotation_range=10,
                                       width_shift_range=10,
                                       height_shift_range=10,
                                       zoom_range=0.3,
                                       horizontal_flip=True,
                                       vertical_flip=True,
                                       fill_mode='reflect')
    
  return img_data_gen, mask_data_gen

# %%
# --------------------------------
# Create the class for the dataset
# --------------------------------

from PIL import Image

class CustomDataset(tf.keras.utils.Sequence):

  """
    CustomDataset inheriting from tf.keras.utils.Sequence.

    3 main methods:
      - __init__: save dataset params like directory, filenames..
      - __len__: return the total number of samples in the dataset
      - __getitem__: return a sample from the dataset

    Note: 
      - the custom dataset return a single sample from the dataset. Then, we use 
        a tf.data.Dataset object to group samples into batches.
      - in this case we have a different structure of the dataset in memory. 
        We have all the images in the same folder and the training and validation splits
        are defined in text files.

  """

  def __init__(self, dataset_dir, which_subset, img_generator=None, mask_generator=None, 
               preprocessing_function=None, out_shape=[500, 500]):
    import json
    
    subset_file = os.path.join('/content', 'dataset_split.json')
    with open(subset_file, 'r') as f:
      split = json.load(f)
    
    teams = ['Bipbip', 'Pead', 'Roseau', 'Weedelec']
    plants = ['Haricot', 'Mais']
    
    subset_filenames = []
    
    for t in teams:
      for p in plants:
        
        for img_name in split[which_subset][t][p]:
          subset_filenames.append(img_name) 

    self.which_subset = which_subset
    self.dataset_dir = dataset_dir
    self.subset_filenames = subset_filenames
    self.img_generator = img_generator
    self.mask_generator = mask_generator
    self.preprocessing_function = preprocessing_function
    self.out_shape = out_shape

  def __len__(self):
    return len(self.subset_filenames)

  def __getitem__(self, index):
    # Read Image
    curr_filename = self.subset_filenames[index]
    img = Image.open(os.path.join(self.dataset_dir, self.which_subset, 'images', curr_filename[0] + '.' + curr_filename[1]))
    mask = Image.open(os.path.join(self.dataset_dir, self.which_subset, 'masks', curr_filename[0] + '.png'))   

    # Resize image and mask
    img = img.resize(self.out_shape) #size – The requested size in pixels, as a 2-tuple: (width, height). !!!!!!!!!!! ATTENTION !!!!!!!!!
    mask = mask.resize(self.out_shape, resample=Image.NEAREST) 

    img_arr = np.array(img)
    mask_arr = np.array(mask)
    
    # RGB to target
    # -------------
    new_mask_arr = np.zeros(mask_arr.shape[:2], dtype=mask_arr.dtype)

    # Use RGB dictionary in 'RGBtoTarget.txt' to convert RGB to target
    new_mask_arr[np.where(np.all(mask_arr == [0, 0, 0], axis=-1))] = 0
    new_mask_arr[np.where(np.all(mask_arr == [216, 124, 18], axis=-1))] = 0
    new_mask_arr[np.where(np.all(mask_arr == [255, 255, 255], axis=-1))] = 1
    new_mask_arr[np.where(np.all(mask_arr == [216, 67, 82], axis=-1))] = 2

    mask_arr = np.expand_dims(new_mask_arr, -1)
    # -------------

    # in this dataset 255 mask label is assigned to an additional class, which corresponds 
    # to the contours of the objects. We remove it for simplicity.
    #mask_arr[mask_arr == 255] = 0  

    if self.which_subset == 'training':
      if self.img_generator is not None and self.mask_generator is not None:
        # Perform data augmentation
        # We can get a random transformation from the ImageDataGenerator using get_random_transform
        # and we can apply it to the image using apply_transform
        img_t = self.img_generator.get_random_transform(img_arr.shape, seed=SEED)
        mask_t = self.mask_generator.get_random_transform(mask_arr.shape, seed=SEED)
        img_arr = self.img_generator.apply_transform(img_arr, img_t)
        # ImageDataGenerator use bilinear interpolation for augmenting the images.
        # Thus, when applied to the masks it will output 'interpolated classes', which
        # is an unwanted behaviour. As a trick, we can transform each class mask 
        # separately and then we can cast to integer values (as in the binary segmentation notebook).
        # Finally, we merge the augmented binary masks to obtain the final segmentation mask.
        out_mask = np.zeros_like(mask_arr)
        for c in np.unique(mask_arr):
          if c > 0:
            curr_class_arr = np.float32(mask_arr == c)
            curr_class_arr = self.mask_generator.apply_transform(curr_class_arr, mask_t)
            # from [0, 1] to {0, 1}
            curr_class_arr = np.uint8(curr_class_arr)
            # recover original class
            curr_class_arr = curr_class_arr * c 
            out_mask += curr_class_arr
    else:
      out_mask = mask_arr
    
    if self.preprocessing_function is not None:
        img_arr = self.preprocessing_function(img_arr)

    return img_arr, np.float32(out_mask)

# %%
# ------------------------------------------------------------------
# Create train and validation dataset objects using the custom class
# ------------------------------------------------------------------
def create_dataset(img_data_gen, mask_data_gen, img_h, img_w, bs, num_classes):

  # Training
  # --------
  dataset = CustomDataset('/content/Development_Dataset_15',
                          'training', 
                          img_generator=img_data_gen, 
                          mask_generator=mask_data_gen,
                          out_shape=[img_w, img_h] # size – The requested size in pixels, as a 2-tuple: (width, height).
                          )
  
  train_dataset = tf.data.Dataset.from_generator(lambda: dataset,
                                                 output_types=(tf.float32, tf.float32),
                                                 output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))
  train_dataset = train_dataset.batch(bs)

  train_dataset = train_dataset.repeat()
  # --------

  # Validation
  # ----------
  dataset_valid = CustomDataset('/content/Development_Dataset_15',
                               'validation',
                               out_shape=[img_w, img_h] # size – The requested size in pixels, as a 2-tuple: (width, height).
                               )
   
  valid_dataset = tf.data.Dataset.from_generator(lambda: dataset_valid,
                                                 output_types=(tf.float32, tf.float32),
                                                 output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))
  valid_dataset = valid_dataset.batch(bs)

  valid_dataset = valid_dataset.repeat()
  # ----------

  return train_dataset, dataset, valid_dataset, dataset_valid

# %% [markdown]
# # Data generator test

# %%
# Let's test data generator
# -------------------------

apply_data_augmentation = True

tmp_img_h = 368
tmp_img_w = 512

[img_data_gen, mask_data_gen] = data_generator(apply_data_augmentation)

[train_dataset, dataset, valid_dataset, dataset_valid] = create_dataset(img_data_gen, mask_data_gen, img_h = tmp_img_h, img_w = tmp_img_w, bs = 8, num_classes = 3)

import time
from matplotlib import cm
import matplotlib.pyplot as plt

# %matplotlib inline

# Assign a color to each class
evenly_spaced_interval = np.linspace(0, 1, 3)
colors = [cm.rainbow(x) for x in evenly_spaced_interval]

iterator = iter(train_dataset)

# %%
augmented_img, target = next(iterator)
augmented_img.shape
# Out:
# TensorShape([8, 368, 512, 3])

# %%
fig, ax = plt.subplots(1, 2)

augmented_img = augmented_img[0]   # First element
augmented_img = augmented_img  # denormalize

target = np.array(target[0, ..., 0])   # First element (squeezing channel dimension)

print(np.unique(target))

target_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, 3):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(augmented_img))
ax[1].imshow(np.uint8(target_img))

plt.show()


'''
augmented_img, target = next(iterator)

rgb_img = cv2.imread('/content/Development_Dataset_15/training/images/Pead_mais_00070_i900.jpg', cv2.IMREAD_UNCHANGED)  # open image
proper_h = 384
proper_w = 512
    # resize to see how it works with kernels

    # get exgreen
exgr = None
exgr_mask = None
exgr = exgreen(rgb_img)
print("Exgr shape: ", exgr.shape)

exgr_mask = thresh(exgr, 50)
#exgr.resize([proper_h, proper_w, 3])
im_gray_plt(exgr)
im_gray_plt(exgr_mask)
'''
# Out:
# [0. 1. 2.]
# '\naugmented_img, target = next(iterator)\n\nrgb_img = cv2.imread(\'/content/Development_Dataset_15/training/images/Pead_mais_00070_i900.jpg\', cv2.IMREAD_UNCHANGED)  # open image\nproper_h = 384\nproper_w = 512\n    # resize to see how it works with kernels\n\n    # get exgreen\nexgr = None\nexgr_mask = None\nexgr = exgreen(rgb_img)\nprint("Exgr shape: ", exgr.shape)\n\nexgr_mask = thresh(exgr, 50)\n#exgr.resize([proper_h, proper_w, 3])\nim_gray_plt(exgr)\nim_gray_plt(exgr_mask)\n'

# %% [markdown]
# # Model setup

# %%
from keras import backend as K

class MaxUnpooling2D(tf.keras.layers.Layer):
    def __init__(self, size=(2, 2), **kwargs):
        super(MaxUnpooling2D, self).__init__(**kwargs)
        self.size = size

    def call(self, inputs, output_shape=None):
        updates, mask = inputs[0], inputs[1]
        with tf.compat.v1.variable_scope(self.name):
            mask = K.cast(mask, 'int32')
            input_shape = tf.shape(updates, out_type='int32')
            #print(updates.shape)
            #print(mask.shape)
            if output_shape is None:
                output_shape = (
                    input_shape[0],
                    input_shape[1] * self.size[0],
                    input_shape[2] * self.size[1],
                    input_shape[3])

            ret = tf.scatter_nd(K.expand_dims(K.flatten(mask)),
                                  K.flatten(updates),
                                  [K.prod(output_shape)])

            input_shape = updates.shape
            out_shape = [-1,
                         input_shape[1] * self.size[0],
                         input_shape[2] * self.size[1],
                         input_shape[3]]
        return K.reshape(ret, out_shape)

    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'size': self.size
        })
        return config

    def compute_output_shape(self, input_shape):
        mask_shape = input_shape[1]
        return (
                mask_shape[0],
                mask_shape[1]*self.size[0],
                mask_shape[2]*self.size[1],
                mask_shape[3]
                )

# %%
# -------------------------------------------------
# Define the unet model (without transfer learning)
# -------------------------------------------------

def define_bonnet(input_size = (384, 512, 3)):

    inputs = tf.keras.Input(input_size)

    conv1 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (5, 5), strides = (1, 1), padding = 'same')(inputs)
    bn1 = tf.keras.layers.BatchNormalization(momentum=0.9)(conv1)
    out1 = tf.keras.layers.ReLU()(bn1)

    # Downsampling
    # ------------

    # Residual block 1
    b1_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(out1)
    b1_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b1_conv1)
    b1_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b1_conv2)
    b1_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b1_conv3)
    rout1 = tf.keras.layers.Add()([b1_conv4, out1])

    # Residual block 2
    b2_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout1)
    b2_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b2_conv1)
    b2_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b2_conv2)
    b2_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b2_conv3)
    rout2 = tf.keras.layers.Add()([b2_conv4, rout1])

    # Residual block 3
    b3_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout2)
    b3_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b3_conv1)
    b3_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b3_conv2)
    b3_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b3_conv3)
    rout3 = tf.keras.layers.Add()([b3_conv4, rout2])

    # Pooling 1
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides = (2, 2))(rout3)

    # Residual block 4
    b4_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(pool1)
    b4_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b4_conv1)
    b4_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b4_conv2)
    b4_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b4_conv3)
    rout4 = tf.keras.layers.Add()([b4_conv4, pool1])

    # Residual block 5
    b5_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout4)
    b5_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b5_conv1)
    b5_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b5_conv2)
    b5_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b5_conv3)
    rout5 = tf.keras.layers.Add()([b5_conv4, rout4])

    # Residual block 6
    b6_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout5)
    b6_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b6_conv1)
    b6_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b6_conv2)
    b6_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b6_conv3)
    rout6 = tf.keras.layers.Add()([b6_conv4, rout5])

    # Pooling 2
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides = (2, 2))(rout6)

    # Residual block 7
    b7_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(pool2)
    b7_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b7_conv1)
    b7_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b7_conv2)
    b7_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b7_conv3)
    rout7 = tf.keras.layers.Add()([b7_conv4, pool2])

    # Residual block 8
    b8_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout7)
    b8_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b8_conv1)
    b8_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b8_conv2)
    b8_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b8_conv3)
    rout8 = tf.keras.layers.Add()([b8_conv4, rout7])

    # Residual block 9
    b9_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout8)
    b9_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b9_conv1)
    b9_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b9_conv2)
    b9_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b9_conv3)
    rout9 = tf.keras.layers.Add()([b9_conv4, rout8])

    # Pooling 3
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides = (2, 2))(rout9)

    # Residual block 10
    b10_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(pool3)
    b10_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b10_conv1)
    b10_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b10_conv2)
    b10_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b10_conv3)
    rout10 = tf.keras.layers.Add()([b10_conv4, pool3])

    # Residual block 11
    b11_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout10)
    b11_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b11_conv1)
    b11_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b11_conv2)
    b11_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b11_conv3)
    rout11 = tf.keras.layers.Add()([b11_conv4, rout10])

    # Residual block 12
    b12_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout11)
    b12_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b12_conv1)
    b12_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b12_conv2)
    b12_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b12_conv3)
    rout12 = tf.keras.layers.Add()([b12_conv4, rout11])

    # Pooling 4
    pool4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides = (2, 2))(rout12)

    #-----------------------------------------------

    # Decoder
    # -------

    # Unpooling with shared indexes
    unpool1 = tf.keras.layers.UpSampling2D()(pool4)

    # Residual block 13
    b13_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(unpool1)
    b13_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b13_conv1)
    b13_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b13_conv2)
    b13_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b13_conv3)
    rout13 = tf.keras.layers.Add()([b13_conv4, unpool1])

    # Residual block 14
    b14_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout13)
    b14_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b14_conv1)
    b14_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b14_conv2)
    b14_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b14_conv3)
    rout14 = tf.keras.layers.Add()([b14_conv4, rout13])

    # Residual block 15
    b15_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout14)
    b15_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b15_conv1)
    b15_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b15_conv2)
    b15_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b15_conv3)
    rout15 = tf.keras.layers.Add()([b15_conv4, rout14])

    # Unpooling with shared indexes
    unpool2 = tf.keras.layers.UpSampling2D()(rout15)

    # Residual block 16
    b16_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(unpool2)
    b16_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b16_conv1)
    b16_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b16_conv2)
    b16_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b16_conv3)
    rout16 = tf.keras.layers.Add()([b16_conv4, unpool2])

    # Residual block 17
    b17_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout16)
    b17_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b17_conv1)
    b17_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b17_conv2)
    b17_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b17_conv3)
    rout17 = tf.keras.layers.Add()([b17_conv4, rout16])

    # Residual block 18
    b18_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout17)
    b18_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b18_conv1)
    b18_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b18_conv2)
    b18_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b18_conv3)
    rout18 = tf.keras.layers.Add()([b18_conv4, rout17])

    # Unpooling with shared indexes
    unpool3 = tf.keras.layers.UpSampling2D()(rout18)

    # Residual block 19
    b19_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(unpool3)
    b19_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b19_conv1)
    b19_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b19_conv2)
    b19_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b19_conv3)
    rout19 = tf.keras.layers.Add()([b19_conv4, unpool3])

    # Residual block 20
    b20_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout19)
    b20_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b20_conv1)
    b20_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b20_conv2)
    b20_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b20_conv3)
    rout20 = tf.keras.layers.Add()([b20_conv4, rout19])

    # Residual block 21
    b21_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout20)
    b21_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b20_conv1)
    b21_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b20_conv2)
    b21_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b20_conv3)
    rout21 = tf.keras.layers.Add()([b21_conv4, rout20])

    # Unpooling with shared indexes
    unpool4 = tf.keras.layers.UpSampling2D()(rout21)

    # Residual block 22
    b22_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(unpool4)
    b22_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b22_conv1)
    b22_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b22_conv2)
    b22_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b22_conv3)
    rout22 = tf.keras.layers.Add()([b22_conv4, unpool4])

    # Residual block 23
    b23_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout22)
    b23_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b23_conv1)
    b23_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b23_conv2)
    b23_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b23_conv3)
    rout23 = tf.keras.layers.Add()([b23_conv4, rout22])

    # Residual block 24
    b24_conv1 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(rout23)
    b24_conv2 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (5, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b24_conv1)
    b24_conv3 = tf.keras.layers.Conv2D(filters = 8, kernel_size = (1, 5), strides = (1, 1), padding = 'same', activation = 'relu')(b24_conv2)
    b24_conv4 = tf.keras.layers.Conv2D(filters = 16, kernel_size = (1, 1), strides = (1, 1), padding = 'same', activation = 'relu')(b24_conv3)
    rout24 = tf.keras.layers.Add()([b24_conv4, rout23])

    # CONV(1,1) with 3 kernels
    out = tf.keras.layers.Conv2D(filters = 3, # only 1 output neuron since the classification is binary: output => 0 == background, 1 == object
                                 kernel_size = (1, 1), # => FC layer convolutionalized
                                 strides = (1, 1), # stride of a FC layer
                                 padding = 'same', # or same: kernel is (1,1) and stride (1,1) so is not important
                                 activation='softmax')(rout24)

    model = tf.keras.Model(inputs = inputs, outputs = out)

    # Visualize created model as a table
    model.summary()

    return model

# %%
# -----------------------------------------------------------------
# Define the model created from scratch (without transfer learning)
# -----------------------------------------------------------------
def define_model(depth, start_f, num_classes, dynamic_input_shape, img_h, img_w):

    model = tf.keras.Sequential()
    
    # Encoder
    # -------
    for i in range(depth):
        
        if i == 0:
            if dynamic_input_shape:
                input_shape = [None, None, 3]
            else:
                input_shape = [img_h, img_w, 3]
        else:
            input_shape=[None]
        
        model.add(tf.keras.layers.Conv2D(filters=start_f, 
                                         kernel_size=(3, 3),
                                         strides=(1, 1),
                                         padding='same',
                                         input_shape=input_shape))
        model.add(tf.keras.layers.ReLU())
        model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))

        start_f *= 2

    # Bottleneck => does not have pooling
    model.add(tf.keras.layers.Conv2D(filters=start_f, kernel_size=(3, 3), strides=(1, 1), padding='same'))
    model.add(tf.keras.layers.ReLU())
    
    start_f = start_f // 2 # Start to decrease the number of features
        
    # Decoder: recover details
    # -------
    for i in range(depth):
        model.add(tf.keras.layers.UpSampling2D(2, interpolation='bilinear')) # 2 means that double the input dimension
        # Now conv + ReLU transform the upsampled features into dense features
        model.add(tf.keras.layers.Conv2D(filters=start_f,
                                         kernel_size=(3, 3),
                                         strides=(1, 1),
                                         padding='same'))
        model.add(tf.keras.layers.ReLU())

        start_f = start_f // 2

    # Prediction Layer i.e. classification layer => FC layer convolutionalized
    # ----------------
    model.add(tf.keras.layers.Conv2D(filters=num_classes, # only 1 output neuron since the classification is binary: output => 0 == background, 1 == object
                                     kernel_size=(1, 1), # => FC layer convolutionalized
                                     strides=(1, 1), # stride of a FC layer
                                     padding='same', # or same: kernel is (1,1) and stride (1,1) so is not important
                                     activation='softmax'))
    
    # Visualize created model as a table
    model.summary()

    return model

# %%
# -------------------------------------------------
# Define the unet model (without transfer learning)
# -------------------------------------------------
def define_unet(pretrained_weights, input_size):

    inputs = tf.keras.Input(input_size)

    conv1 = tf.keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = tf.keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = tf.keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = tf.keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = tf.keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = tf.keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = tf.keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = tf.keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = tf.keras.layers.Dropout(0.5)(conv4)
    pool4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = tf.keras.layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = tf.keras.layers.Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = tf.keras.layers.Dropout(0.5)(conv5)

    up6 = tf.keras.layers.Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(tf.keras.layers.UpSampling2D(size = (2,2))(drop5))
    merge6 = tf.keras.layers.concatenate([drop4,up6], axis = 3)
    conv6 = tf.keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = tf.keras.layers.Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = tf.keras.layers.Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(tf.keras.layers.UpSampling2D(size = (2,2))(conv6))
    merge7 = tf.keras.layers.concatenate([conv3,up7], axis = 3)
    conv7 = tf.keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = tf.keras.layers.Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = tf.keras.layers.Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(tf.keras.layers.UpSampling2D(size = (2,2))(conv7))
    merge8 = tf.keras.layers.concatenate([conv2,up8], axis = 3)
    conv8 = tf.keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = tf.keras.layers.Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = tf.keras.layers.Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(tf.keras.layers.UpSampling2D(size = (2,2))(conv8))
    merge9 = tf.keras.layers.concatenate([conv1,up9], axis = 3)
    conv9 = tf.keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = tf.keras.layers.Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = tf.keras.layers.Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

    conv10 = tf.keras.layers.Conv2D(filters = 3, # only 1 output neuron since the classification is binary: output => 0 == background, 1 == object
                                    kernel_size = (1, 1), # => FC layer convolutionalized
                                    strides = (1, 1), # stride of a FC layer
                                    padding = 'same', # or same: kernel is (1,1) and stride (1,1) so is not important
                                    activation='softmax')(conv9)

    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    if(pretrained_weights):
    	model.load_weights(pretrained_weights)

    # Visualize created model as a table
    model.summary()

    return model

# %%
'''
model = unet()


model = create_model(depth=4, 
                     start_f=8, 
                     num_classes=3, 
                     dynamic_input_shape=False)
'''
# Out:
# '\nmodel = unet()\n\n\nmodel = create_model(depth=4, \n                     start_f=8, \n                     num_classes=3, \n                     dynamic_input_shape=False)\n'

# %%
# Here we define the intersection over union for each class in the batch.
# Then we compute the final iou as the mean over classes
def meanIoU(y_true, y_pred):

  # get predicted class from softmax
  y_pred = tf.expand_dims(tf.argmax(y_pred, -1), -1)

  per_class_iou = []

  for i in range(1,3): # exclude the background class 0

    # Get prediction and target related to only a single class (i)
    class_pred = tf.cast(tf.where(y_pred == i, 1, 0), tf.float32)
    class_true = tf.cast(tf.where(y_true == i, 1, 0), tf.float32)
    intersection = tf.reduce_sum(class_true * class_pred)
    union = tf.reduce_sum(class_true) + tf.reduce_sum(class_pred) - intersection
    
    iou = (intersection + 1e-7) / (union + 1e-7)
    per_class_iou.append(iou)

  return tf.reduce_mean(per_class_iou)

# %%
# -----------------
# Compile the model
# -----------------
def compile_model(model, lr):

  # Optimization params
  # -------------------

  # Loss
  # ----
  # Sparse Categorical Crossentropy to use integers (mask) instead of one-hot encoded labels
  loss = tf.keras.losses.SparseCategoricalCrossentropy()
  # ----

  # Optimization function
  # ---------------------
  optimizer = tfa.optimizers.RectifiedAdam(learning_rate=lr) #tf.keras.optimizers.Adam(learning_rate=lr)
  # ---------------------

  # Validation metrics
  # ------------------
  mIoU = meanIoU
  metrics = ['accuracy', mIoU]
  # ------------------

  # Compile Model
  # -------------
  model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
  # -------------

  # -------------------
  
  return model

# %%
# -----------------
# Set the callbacks
# -----------------
def set_callbacks(type, model_checkpoint, visualize_tensorboard, early_stop, reduce_lr_on_plateau):
  
  import os
  from datetime import datetime

  cwd = os.getcwd()

  exps_dir = os.path.join('/content/drive/My Drive/Challenge_2/', 'segmentation_experiments')
  if not os.path.exists(exps_dir):
    os.makedirs(exps_dir)

  model_name = type

  exp_dir = os.path.join(exps_dir, model_name)
  if not os.path.exists(exp_dir):
    os.makedirs(exp_dir)
    
  callbacks = []

  # Model checkpoint
  # ----------------
  if model_checkpoint:
    ckpt_dir = os.path.join(exp_dir, 'ckpts')
    if not os.path.exists(ckpt_dir):
      os.makedirs(ckpt_dir)

    ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp_{epoch:02d}.ckpt'), 
                                                       save_weights_only=True,
                                                       save_best_only=True)  # False to save the model directly
    callbacks.append(ckpt_callback)
  # ----------------

  # Visualize Learning on Tensorboard
  # ---------------------------------
  if visualize_tensorboard:
    tb_dir = os.path.join(exp_dir, 'tb_logs')
    if not os.path.exists(tb_dir):
      os.makedirs(tb_dir)
    
    # By default shows losses and metrics for both training and validation
    tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir,
                                                 profile_batch=0,
                                                 histogram_freq=1)  # if 1 shows weights histograms
    callbacks.append(tb_callback)
  # ---------------------------------

  # Early Stopping
  # --------------
  if early_stop:
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                                   patience = 15,
                                                   restore_best_weights=True)
    callbacks.append(es_callback)
  # --------------

  # Reduce Learning rate on plateau
  # -------------------------------
  if reduce_lr_on_plateau:
    rlr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                        factor=0.5, 
                                                        patience=4, 
                                                        verbose=1, 
                                                        mode='auto', 
                                                        min_delta=0.0001)
    callbacks.append(rlr_callback)
  # -------------------------------

  return callbacks

# %%
# -----------
# Train model
# -----------
def train_model(model, train_dataset, dataset, valid_dataset, dataset_valid, callbacks, num_epochs, bs):
  
  history_model = model.fit(x = train_dataset,
                            epochs = num_epochs,  #### set repeat in training dataset
                            steps_per_epoch = int(np.ceil(len(dataset) / bs)),
                            validation_data = valid_dataset,
                            validation_steps = int(np.ceil(len(dataset_valid) / bs)), 
                            callbacks = callbacks)
  
  return history_model

# %% [markdown]
# # Training

# %%
# --------------------------------------
# Train the model with transfer learning
# --------------------------------------
def train_bonnet():
  
  apply_data_augmentation = True

  img_h = 768
  img_w = 1024

  num_classes = 3

  bs = 6

  lr = 5e-4

  num_epochs = 100

  model_checkpoint = True
  visualize_tensorboard = False
  early_stop = True
  reduce_lr_on_plateau = True

  print('--------------------------------------------')
  print('Image heigth                      ---> ' + str(img_h))
  print('Image width                       ---> ' + str(img_w))
  print('Batch size                        ---> ' + str(bs))
  print('Learning rate                     ---> ' + str(lr))
  print('Number of epochs                  ---> ' + str(num_epochs))
  print('Model checkpoint                  ---> ' + str(model_checkpoint))
  print('Visualize tensorboars             ---> ' + str(visualize_tensorboard))
  print('Early stopping                    ---> ' + str(early_stop))
  print('Reduce learning rate on plateau   ---> ' + str(reduce_lr_on_plateau))
  print('--------------------------------------------')

  [img_data_gen, mask_data_gen] = data_generator(apply_data_augmentation)

  [train_dataset, dataset, valid_dataset, dataset_valid] = create_dataset(img_data_gen, mask_data_gen, img_h = img_h, img_w = img_w, bs = bs, num_classes = num_classes)

  model = define_bonnet(input_size = (img_h, img_w, 3))
  '''
  exps_dir = os.path.join('/content/drive/My Drive/Challenge_2/', 'segmentation_experiments')
  model_name = 'bonnet_rect'
  exp_dir = os.path.join(exps_dir, model_name)
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  latest = tf.train.latest_checkpoint(ckpt_dir)
  print(latest)
  model.load_weights(latest)
  '''
  model = compile_model(model, lr = lr)

  callbacks = set_callbacks('bonnet_rect', model_checkpoint = model_checkpoint, visualize_tensorboard = visualize_tensorboard, early_stop = early_stop, reduce_lr_on_plateau = reduce_lr_on_plateau)

  history = train_model(model, train_dataset, dataset, valid_dataset, dataset_valid, callbacks, num_epochs = num_epochs, bs = bs)

  plot_history(history)

  return model, history

# %%
# --------------------------------------
# Train the model with transfer learning
# --------------------------------------
def train_unet():
  
  apply_data_augmentation = True

  img_h = 384
  img_w = 512

  num_classes = 3

  bs = 10

  lr = 5e-4

  num_epochs = 100

  model_checkpoint = True
  visualize_tensorboard = False
  early_stop = True
  reduce_lr_on_plateau = True

  print('--------------------------------------------')
  print('Image heigth                      ---> ' + str(img_h))
  print('Image width                       ---> ' + str(img_w))
  print('Batch size                        ---> ' + str(bs))
  print('Learning rate                     ---> ' + str(lr))
  print('Number of epochs                  ---> ' + str(num_epochs))
  print('Model checkpoint                  ---> ' + str(model_checkpoint))
  print('Visualize tensorboars             ---> ' + str(visualize_tensorboard))
  print('Early stopping                    ---> ' + str(early_stop))
  print('Reduce learning rate on plateau   ---> ' + str(reduce_lr_on_plateau))
  print('--------------------------------------------')

  [img_data_gen, mask_data_gen] = data_generator(apply_data_augmentation)

  [train_dataset, dataset, valid_dataset, dataset_valid] = create_dataset(img_data_gen, mask_data_gen, img_h = img_h, img_w = img_w, bs = bs, num_classes = num_classes)

  model = define_unet(pretrained_weights = None, input_size = (img_h, img_w, 3))
  '''
  exps_dir = os.path.join('/content/drive/My Drive/Challenge_2/', 'segmentation_experiments')
  model_name = 'CNN_Dec08_02-03-33'
  exp_dir = os.path.join(exps_dir, model_name)
  ckpt_dir = os.path.join(exp_dir, 'ckpts')
  latest = tf.train.latest_checkpoint(ckpt_dir)
  print(latest)
  model.load_weights(latest)
  '''

  '''
  model = define_model(depth = 5, 
                       start_f = 8, 
                       num_classes = num_classes, 
                       dynamic_input_shape=False,
                       img_h=img_h,
                       img_w=img_w)
  '''
  model = compile_model(model, lr = lr)

  callbacks = set_callbacks('unet', model_checkpoint = model_checkpoint, visualize_tensorboard = visualize_tensorboard, early_stop = early_stop, reduce_lr_on_plateau = reduce_lr_on_plateau)

  history = train_model(model, train_dataset, dataset, valid_dataset, dataset_valid, callbacks, num_epochs = num_epochs, bs = bs)

  plot_history(history)

  return model, history

# %% [markdown]
# # Plots

# %%
# ------------------------------------------------------------------------------
# Plot the history of the trained model (loss, val_loss; accuracy, val_accuracy)
# ------------------------------------------------------------------------------
def plot_history(history):
  from matplotlib import pyplot

  pyplot.figure()
  pyplot.plot(history.history['loss'], label='train')
  pyplot.plot(history.history['val_loss'], label='test')
  pyplot.legend()
  pyplot.show()

  pyplot.figure()
  pyplot.plot(history.history['accuracy'], label='train')
  pyplot.plot(history.history['val_accuracy'], label='test')
  pyplot.legend()
  pyplot.show()

# %% [markdown]
# # Execution

# %% [markdown]
# ## Unet training

# %%
[model, history] = train_bonnet()
# Out:
# --------------------------------------------
# Image heigth                      ---> 384
# Image width                       ---> 512
# Batch size                        ---> 10
# Learning rate                     ---> 0.0005
# Number of epochs                  ---> 100
# Model checkpoint                  ---> True
# Visualize tensorboars             ---> False
# Early stopping                    ---> True
# Reduce learning rate on plateau   ---> True
# --------------------------------------------
# Model: "functional_41"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_29 (InputLayer)           [(None, 384, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_1054 (Conv2D)            (None, 384, 512, 16) 1216        input_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 384, 512, 16) 64          conv2d_1054[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 384, 512, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_1055 (Conv2D)            (None, 384, 512, 8)  136         re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv2d_1056 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1055[0][0]
# __________________________________________________________________________________________________
# conv2d_1057 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1056[0][0]
# __________________________________________________________________________________________________
# conv2d_1058 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1057[0][0]
# __________________________________________________________________________________________________
# add_150 (Add)                   (None, 384, 512, 16) 0           conv2d_1058[0][0]
#                                                                  re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv2d_1059 (Conv2D)            (None, 384, 512, 8)  136         add_150[0][0]
# __________________________________________________________________________________________________
# conv2d_1060 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1059[0][0]
# __________________________________________________________________________________________________
# conv2d_1061 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1060[0][0]
# __________________________________________________________________________________________________
# conv2d_1062 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1061[0][0]
# __________________________________________________________________________________________________
# add_151 (Add)                   (None, 384, 512, 16) 0           conv2d_1062[0][0]
#                                                                  add_150[0][0]
# __________________________________________________________________________________________________
# conv2d_1063 (Conv2D)            (None, 384, 512, 8)  136         add_151[0][0]
# __________________________________________________________________________________________________
# conv2d_1064 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1063[0][0]
# __________________________________________________________________________________________________
# conv2d_1065 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1064[0][0]
# __________________________________________________________________________________________________
# conv2d_1066 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1065[0][0]
# __________________________________________________________________________________________________
# add_152 (Add)                   (None, 384, 512, 16) 0           conv2d_1066[0][0]
#                                                                  add_151[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_118 (MaxPooling2D (None, 192, 256, 16) 0           add_152[0][0]
# __________________________________________________________________________________________________
# conv2d_1067 (Conv2D)            (None, 192, 256, 8)  136         max_pooling2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_1068 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1067[0][0]
# __________________________________________________________________________________________________
# conv2d_1069 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1068[0][0]
# __________________________________________________________________________________________________
# conv2d_1070 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1069[0][0]
# __________________________________________________________________________________________________
# add_153 (Add)                   (None, 192, 256, 16) 0           conv2d_1070[0][0]
#                                                                  max_pooling2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_1071 (Conv2D)            (None, 192, 256, 8)  136         add_153[0][0]
# __________________________________________________________________________________________________
# conv2d_1072 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1071[0][0]
# __________________________________________________________________________________________________
# conv2d_1073 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1072[0][0]
# __________________________________________________________________________________________________
# conv2d_1074 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1073[0][0]
# __________________________________________________________________________________________________
# add_154 (Add)                   (None, 192, 256, 16) 0           conv2d_1074[0][0]
#                                                                  add_153[0][0]
# __________________________________________________________________________________________________
# conv2d_1075 (Conv2D)            (None, 192, 256, 8)  136         add_154[0][0]
# __________________________________________________________________________________________________
# conv2d_1076 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1075[0][0]
# __________________________________________________________________________________________________
# conv2d_1077 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1076[0][0]
# __________________________________________________________________________________________________
# conv2d_1078 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1077[0][0]
# __________________________________________________________________________________________________
# add_155 (Add)                   (None, 192, 256, 16) 0           conv2d_1078[0][0]
#                                                                  add_154[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_119 (MaxPooling2D (None, 96, 128, 16)  0           add_155[0][0]
# __________________________________________________________________________________________________
# conv2d_1079 (Conv2D)            (None, 96, 128, 8)   136         max_pooling2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_1080 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1079[0][0]
# __________________________________________________________________________________________________
# conv2d_1081 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1080[0][0]
# __________________________________________________________________________________________________
# conv2d_1082 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1081[0][0]
# __________________________________________________________________________________________________
# add_156 (Add)                   (None, 96, 128, 16)  0           conv2d_1082[0][0]
#                                                                  max_pooling2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_1083 (Conv2D)            (None, 96, 128, 8)   136         add_156[0][0]
# __________________________________________________________________________________________________
# conv2d_1084 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1083[0][0]
# __________________________________________________________________________________________________
# conv2d_1085 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1084[0][0]
# __________________________________________________________________________________________________
# conv2d_1086 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1085[0][0]
# __________________________________________________________________________________________________
# add_157 (Add)                   (None, 96, 128, 16)  0           conv2d_1086[0][0]
#                                                                  add_156[0][0]
# __________________________________________________________________________________________________
# conv2d_1087 (Conv2D)            (None, 96, 128, 8)   136         add_157[0][0]
# __________________________________________________________________________________________________
# conv2d_1088 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1087[0][0]
# __________________________________________________________________________________________________
# conv2d_1089 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1088[0][0]
# __________________________________________________________________________________________________
# conv2d_1090 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1089[0][0]
# __________________________________________________________________________________________________
# add_158 (Add)                   (None, 96, 128, 16)  0           conv2d_1090[0][0]
#                                                                  add_157[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_120 (MaxPooling2D (None, 48, 64, 16)   0           add_158[0][0]
# __________________________________________________________________________________________________
# conv2d_1091 (Conv2D)            (None, 48, 64, 8)    136         max_pooling2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_1092 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1091[0][0]
# __________________________________________________________________________________________________
# conv2d_1093 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1092[0][0]
# __________________________________________________________________________________________________
# conv2d_1094 (Conv2D)            (None, 48, 64, 16)   144         conv2d_1093[0][0]
# __________________________________________________________________________________________________
# add_159 (Add)                   (None, 48, 64, 16)   0           conv2d_1094[0][0]
#                                                                  max_pooling2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_1095 (Conv2D)            (None, 48, 64, 8)    136         add_159[0][0]
# __________________________________________________________________________________________________
# conv2d_1096 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1095[0][0]
# __________________________________________________________________________________________________
# conv2d_1097 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1096[0][0]
# __________________________________________________________________________________________________
# conv2d_1098 (Conv2D)            (None, 48, 64, 16)   144         conv2d_1097[0][0]
# __________________________________________________________________________________________________
# add_160 (Add)                   (None, 48, 64, 16)   0           conv2d_1098[0][0]
#                                                                  add_159[0][0]
# __________________________________________________________________________________________________
# conv2d_1099 (Conv2D)            (None, 48, 64, 8)    136         add_160[0][0]
# __________________________________________________________________________________________________
# conv2d_1100 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1099[0][0]
# __________________________________________________________________________________________________
# conv2d_1101 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1100[0][0]
# __________________________________________________________________________________________________
# conv2d_1102 (Conv2D)            (None, 48, 64, 16)   144         conv2d_1101[0][0]
# __________________________________________________________________________________________________
# add_161 (Add)                   (None, 48, 64, 16)   0           conv2d_1102[0][0]
#                                                                  add_160[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_121 (MaxPooling2D (None, 24, 32, 16)   0           add_161[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_98 (UpSampling2D) (None, 48, 64, 16)   0           max_pooling2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_1103 (Conv2D)            (None, 48, 64, 8)    136         up_sampling2d_98[0][0]
# __________________________________________________________________________________________________
# conv2d_1104 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1103[0][0]
# __________________________________________________________________________________________________
# conv2d_1105 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1104[0][0]
# __________________________________________________________________________________________________
# conv2d_1106 (Conv2D)            (None, 48, 64, 16)   144         conv2d_1105[0][0]
# __________________________________________________________________________________________________
# add_162 (Add)                   (None, 48, 64, 16)   0           conv2d_1106[0][0]
#                                                                  up_sampling2d_98[0][0]
# __________________________________________________________________________________________________
# conv2d_1107 (Conv2D)            (None, 48, 64, 8)    136         add_162[0][0]
# __________________________________________________________________________________________________
# conv2d_1108 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1107[0][0]
# __________________________________________________________________________________________________
# conv2d_1109 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1108[0][0]
# __________________________________________________________________________________________________
# conv2d_1110 (Conv2D)            (None, 48, 64, 16)   144         conv2d_1109[0][0]
# __________________________________________________________________________________________________
# add_163 (Add)                   (None, 48, 64, 16)   0           conv2d_1110[0][0]
#                                                                  add_162[0][0]
# __________________________________________________________________________________________________
# conv2d_1111 (Conv2D)            (None, 48, 64, 8)    136         add_163[0][0]
# __________________________________________________________________________________________________
# conv2d_1112 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1111[0][0]
# __________________________________________________________________________________________________
# conv2d_1113 (Conv2D)            (None, 48, 64, 8)    328         conv2d_1112[0][0]
# __________________________________________________________________________________________________
# conv2d_1114 (Conv2D)            (None, 48, 64, 16)   144         conv2d_1113[0][0]
# __________________________________________________________________________________________________
# add_164 (Add)                   (None, 48, 64, 16)   0           conv2d_1114[0][0]
#                                                                  add_163[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_99 (UpSampling2D) (None, 96, 128, 16)  0           add_164[0][0]
# __________________________________________________________________________________________________
# conv2d_1115 (Conv2D)            (None, 96, 128, 8)   136         up_sampling2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_1116 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1115[0][0]
# __________________________________________________________________________________________________
# conv2d_1117 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1116[0][0]
# __________________________________________________________________________________________________
# conv2d_1118 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1117[0][0]
# __________________________________________________________________________________________________
# add_165 (Add)                   (None, 96, 128, 16)  0           conv2d_1118[0][0]
#                                                                  up_sampling2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_1119 (Conv2D)            (None, 96, 128, 8)   136         add_165[0][0]
# __________________________________________________________________________________________________
# conv2d_1120 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1119[0][0]
# __________________________________________________________________________________________________
# conv2d_1121 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1120[0][0]
# __________________________________________________________________________________________________
# conv2d_1122 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1121[0][0]
# __________________________________________________________________________________________________
# add_166 (Add)                   (None, 96, 128, 16)  0           conv2d_1122[0][0]
#                                                                  add_165[0][0]
# __________________________________________________________________________________________________
# conv2d_1123 (Conv2D)            (None, 96, 128, 8)   136         add_166[0][0]
# __________________________________________________________________________________________________
# conv2d_1124 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1123[0][0]
# __________________________________________________________________________________________________
# conv2d_1125 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1124[0][0]
# __________________________________________________________________________________________________
# conv2d_1126 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1125[0][0]
# __________________________________________________________________________________________________
# add_167 (Add)                   (None, 96, 128, 16)  0           conv2d_1126[0][0]
#                                                                  add_166[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_100 (UpSampling2D (None, 192, 256, 16) 0           add_167[0][0]
# __________________________________________________________________________________________________
# conv2d_1127 (Conv2D)            (None, 192, 256, 8)  136         up_sampling2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_1128 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1127[0][0]
# __________________________________________________________________________________________________
# conv2d_1129 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1128[0][0]
# __________________________________________________________________________________________________
# conv2d_1130 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1129[0][0]
# __________________________________________________________________________________________________
# add_168 (Add)                   (None, 192, 256, 16) 0           conv2d_1130[0][0]
#                                                                  up_sampling2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_1131 (Conv2D)            (None, 192, 256, 8)  136         add_168[0][0]
# __________________________________________________________________________________________________
# conv2d_1132 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1131[0][0]
# __________________________________________________________________________________________________
# conv2d_1133 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1132[0][0]
# __________________________________________________________________________________________________
# conv2d_1134 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1133[0][0]
# __________________________________________________________________________________________________
# conv2d_1138 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1133[0][0]
# __________________________________________________________________________________________________
# add_169 (Add)                   (None, 192, 256, 16) 0           conv2d_1134[0][0]
#                                                                  add_168[0][0]
# __________________________________________________________________________________________________
# add_170 (Add)                   (None, 192, 256, 16) 0           conv2d_1138[0][0]
#                                                                  add_169[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_101 (UpSampling2D (None, 384, 512, 16) 0           add_170[0][0]
# __________________________________________________________________________________________________
# conv2d_1139 (Conv2D)            (None, 384, 512, 8)  136         up_sampling2d_101[0][0]
# __________________________________________________________________________________________________
# conv2d_1140 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1139[0][0]
# __________________________________________________________________________________________________
# conv2d_1141 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1140[0][0]
# __________________________________________________________________________________________________
# conv2d_1142 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1141[0][0]
# __________________________________________________________________________________________________
# add_171 (Add)                   (None, 384, 512, 16) 0           conv2d_1142[0][0]
#                                                                  up_sampling2d_101[0][0]
# __________________________________________________________________________________________________
# conv2d_1143 (Conv2D)            (None, 384, 512, 8)  136         add_171[0][0]
# __________________________________________________________________________________________________
# conv2d_1144 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1143[0][0]
# __________________________________________________________________________________________________
# conv2d_1145 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1144[0][0]
# __________________________________________________________________________________________________
# conv2d_1146 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1145[0][0]
# __________________________________________________________________________________________________
# add_172 (Add)                   (None, 384, 512, 16) 0           conv2d_1146[0][0]
#                                                                  add_171[0][0]
# __________________________________________________________________________________________________
# conv2d_1147 (Conv2D)            (None, 384, 512, 8)  136         add_172[0][0]
# __________________________________________________________________________________________________
# conv2d_1148 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1147[0][0]
# __________________________________________________________________________________________________
# conv2d_1149 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1148[0][0]
# __________________________________________________________________________________________________
# conv2d_1150 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1149[0][0]
# __________________________________________________________________________________________________
# add_173 (Add)                   (None, 384, 512, 16) 0           conv2d_1150[0][0]
#                                                                  add_172[0][0]
# __________________________________________________________________________________________________
# conv2d_1151 (Conv2D)            (None, 384, 512, 3)  51          add_173[0][0]
# ==================================================================================================
# Total params: 23,003
# Trainable params: 22,971
# Non-trainable params: 32
# __________________________________________________________________________________________________
# Epoch 1/100
# 61/61 [==============================] - 266s 4s/step - loss: 3.7055 - accuracy: 0.6141 - meanIoU: 0.0154 - val_loss: 0.5533 - val_accuracy: 0.9014 - val_meanIoU: 8.2326e-04
# Epoch 2/100
# 61/61 [==============================] - 264s 4s/step - loss: 0
100
# 61/61 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9457 - meanIoU: 0.2302
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 61/61 [==============================] - 262s 4s/step - loss: 0.1475 - accuracy: 0.9457 - meanIoU: 0.2302 - val_loss: 0.2243 - val_accuracy: 0.9184 - val_meanIoU: 0.1941
# Epoch 21/100
# 61/61 [==============================] - 261s 4s/step - loss: 0.1449 - accuracy: 0.9464 - meanIoU: 0.2396 - val_loss: 0.2233 - val_accuracy: 0.9217 - val_meanIoU: 0.1865
# Epoch 22/100
# 61/61 [==============================] - 261s 4s/step - loss: 0.1437 - accuracy: 0.9465 - meanIoU: 0.2413 - val_loss: 0.2216 - val_accuracy: 0.9212 - val_meanIoU: 0.1960
# Epoch 23/100
# 61/61 [==============================] - 263s 4s/step - loss: 0.1424 - accuracy: 0.9469 - meanIoU: 0.2446 - val_loss: 0.2214 - val_accuracy: 0.9208 - val_meanIoU: 0.1995
# Epoch 24/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9472 - meanIoU: 0.2471
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 61/61 [==============================] - 269s 4s/step - loss: 0.1415 - accuracy: 0.9472 - meanIoU: 0.2471 - val_loss: 0.2213 - val_accuracy: 0.9207 - val_meanIoU: 0.2015
# Epoch 25/100
# 61/61 [==============================] - 264s 4s/step - loss: 0.1409 - accuracy: 0.9466 - meanIoU: 0.2347 - val_loss: 0.2299 - val_accuracy: 0.9138 - val_meanIoU: 0.2118
# Epoch 26/100
# 61/61 [==============================] - 264s 4s/step - loss: 0.1403 - accuracy: 0.9468 - meanIoU: 0.2311 - val_loss: 0.2270 - val_accuracy: 0.9148 - val_meanIoU: 0.2099
# Epoch 27/100
# 61/61 [==============================] - 264s 4s/step - loss: 0.1396 - accuracy: 0.9470 - meanIoU: 0.2340 - val_loss: 0.2257 - val_accuracy: 0.9151 - val_meanIoU: 0.2100
# Epoch 28/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9471 - meanIoU: 0.2361
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 61/61 [==============================] - 264s 4s/step - loss: 0.1391 - accuracy: 0.9471 - meanIoU: 0.2361 - val_loss: 0.2244 - val_accuracy: 0.9155 - val_meanIoU: 0.2109
# Epoch 29/100
# 61/61 [==============================] - 263s 4s/step - loss: 0.1381 - accuracy: 0.9473 - meanIoU: 0.2341 - val_loss: 0.2328 - val_accuracy: 0.9113 - val_meanIoU: 0.2176
# Epoch 30/100
# 61/61 [==============================] - 263s 4s/step - loss: 0.1379 - accuracy: 0.9472 - meanIoU: 0.2357 - val_loss: 0.2292 - val_accuracy: 0.9130 - val_meanIoU: 0.2228
# Epoch 31/100
# 61/61 [==============================] - 264s 4s/step - loss: 0.1373 - accuracy: 0.9475 - meanIoU: 0.2394 - val_loss: 0.2269 - val_accuracy: 0.9141 - val_meanIoU: 0.2253

# %%
[model, history] = train_bonnet()
# Out:
# --------------------------------------------
# Image heigth                      ---> 768
# Image width                       ---> 1024
# Batch size                        ---> 6
# Learning rate                     ---> 0.0005
# Number of epochs                  ---> 100
# Model checkpoint                  ---> True
# Visualize tensorboars             ---> False
# Early stopping                    ---> True
# Reduce learning rate on plateau   ---> True
# --------------------------------------------
# Model: "functional_49"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_33 (InputLayer)           [(None, 768, 1024, 3 0
# __________________________________________________________________________________________________
# conv2d_1446 (Conv2D)            (None, 768, 1024, 16 1216        input_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 768, 1024, 16 64          conv2d_1446[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 768, 1024, 16 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_1447 (Conv2D)            (None, 768, 1024, 8) 136         re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv2d_1448 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1447[0][0]
# __________________________________________________________________________________________________
# conv2d_1449 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1448[0][0]
# __________________________________________________________________________________________________
# conv2d_1450 (Conv2D)            (None, 768, 1024, 16 144         conv2d_1449[0][0]
# __________________________________________________________________________________________________
# add_246 (Add)                   (None, 768, 1024, 16 0           conv2d_1450[0][0]
#                                                                  re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv2d_1451 (Conv2D)            (None, 768, 1024, 8) 136         add_246[0][0]
# __________________________________________________________________________________________________
# conv2d_1452 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1451[0][0]
# __________________________________________________________________________________________________
# conv2d_1453 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1452[0][0]
# __________________________________________________________________________________________________
# conv2d_1454 (Conv2D)            (None, 768, 1024, 16 144         conv2d_1453[0][0]
# __________________________________________________________________________________________________
# add_247 (Add)                   (None, 768, 1024, 16 0           conv2d_1454[0][0]
#                                                                  add_246[0][0]
# __________________________________________________________________________________________________
# conv2d_1455 (Conv2D)            (None, 768, 1024, 8) 136         add_247[0][0]
# __________________________________________________________________________________________________
# conv2d_1456 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1455[0][0]
# __________________________________________________________________________________________________
# conv2d_1457 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1456[0][0]
# __________________________________________________________________________________________________
# conv2d_1458 (Conv2D)            (None, 768, 1024, 16 144         conv2d_1457[0][0]
# __________________________________________________________________________________________________
# add_248 (Add)                   (None, 768, 1024, 16 0           conv2d_1458[0][0]
#                                                                  add_247[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_134 (MaxPooling2D (None, 384, 512, 16) 0           add_248[0][0]
# __________________________________________________________________________________________________
# conv2d_1459 (Conv2D)            (None, 384, 512, 8)  136         max_pooling2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_1460 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1459[0][0]
# __________________________________________________________________________________________________
# conv2d_1461 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1460[0][0]
# __________________________________________________________________________________________________
# conv2d_1462 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1461[0][0]
# __________________________________________________________________________________________________
# add_249 (Add)                   (None, 384, 512, 16) 0           conv2d_1462[0][0]
#                                                                  max_pooling2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_1463 (Conv2D)            (None, 384, 512, 8)  136         add_249[0][0]
# __________________________________________________________________________________________________
# conv2d_1464 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1463[0][0]
# __________________________________________________________________________________________________
# conv2d_1465 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1464[0][0]
# __________________________________________________________________________________________________
# conv2d_1466 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1465[0][0]
# __________________________________________________________________________________________________
# add_250 (Add)                   (None, 384, 512, 16) 0           conv2d_1466[0][0]
#                                                                  add_249[0][0]
# __________________________________________________________________________________________________
# conv2d_1467 (Conv2D)            (None, 384, 512, 8)  136         add_250[0][0]
# __________________________________________________________________________________________________
# conv2d_1468 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1467[0][0]
# __________________________________________________________________________________________________
# conv2d_1469 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1468[0][0]
# __________________________________________________________________________________________________
# conv2d_1470 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1469[0][0]
# __________________________________________________________________________________________________
# add_251 (Add)                   (None, 384, 512, 16) 0           conv2d_1470[0][0]
#                                                                  add_250[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_135 (MaxPooling2D (None, 192, 256, 16) 0           add_251[0][0]
# __________________________________________________________________________________________________
# conv2d_1471 (Conv2D)            (None, 192, 256, 8)  136         max_pooling2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_1472 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1471[0][0]
# __________________________________________________________________________________________________
# conv2d_1473 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1472[0][0]
# __________________________________________________________________________________________________
# conv2d_1474 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1473[0][0]
# __________________________________________________________________________________________________
# add_252 (Add)                   (None, 192, 256, 16) 0           conv2d_1474[0][0]
#                                                                  max_pooling2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_1475 (Conv2D)            (None, 192, 256, 8)  136         add_252[0][0]
# __________________________________________________________________________________________________
# conv2d_1476 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1475[0][0]
# __________________________________________________________________________________________________
# conv2d_1477 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1476[0][0]
# __________________________________________________________________________________________________
# conv2d_1478 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1477[0][0]
# __________________________________________________________________________________________________
# add_253 (Add)                   (None, 192, 256, 16) 0           conv2d_1478[0][0]
#                                                                  add_252[0][0]
# __________________________________________________________________________________________________
# conv2d_1479 (Conv2D)            (None, 192, 256, 8)  136         add_253[0][0]
# __________________________________________________________________________________________________
# conv2d_1480 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1479[0][0]
# __________________________________________________________________________________________________
# conv2d_1481 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1480[0][0]
# __________________________________________________________________________________________________
# conv2d_1482 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1481[0][0]
# __________________________________________________________________________________________________
# add_254 (Add)                   (None, 192, 256, 16) 0           conv2d_1482[0][0]
#                                                                  add_253[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_136 (MaxPooling2D (None, 96, 128, 16)  0           add_254[0][0]
# __________________________________________________________________________________________________
# conv2d_1483 (Conv2D)            (None, 96, 128, 8)   136         max_pooling2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_1484 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1483[0][0]
# __________________________________________________________________________________________________
# conv2d_1485 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1484[0][0]
# __________________________________________________________________________________________________
# conv2d_1486 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1485[0][0]
# __________________________________________________________________________________________________
# add_255 (Add)                   (None, 96, 128, 16)  0           conv2d_1486[0][0]
#                                                                  max_pooling2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_1487 (Conv2D)            (None, 96, 128, 8)   136         add_255[0][0]
# __________________________________________________________________________________________________
# conv2d_1488 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1487[0][0]
# __________________________________________________________________________________________________
# conv2d_1489 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1488[0][0]
# __________________________________________________________________________________________________
# conv2d_1490 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1489[0][0]
# __________________________________________________________________________________________________
# add_256 (Add)                   (None, 96, 128, 16)  0           conv2d_1490[0][0]
#                                                                  add_255[0][0]
# __________________________________________________________________________________________________
# conv2d_1491 (Conv2D)            (None, 96, 128, 8)   136         add_256[0][0]
# __________________________________________________________________________________________________
# conv2d_1492 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1491[0][0]
# __________________________________________________________________________________________________
# conv2d_1493 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1492[0][0]
# __________________________________________________________________________________________________
# conv2d_1494 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1493[0][0]
# __________________________________________________________________________________________________
# add_257 (Add)                   (None, 96, 128, 16)  0           conv2d_1494[0][0]
#                                                                  add_256[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_137 (MaxPooling2D (None, 48, 64, 16)   0           add_257[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_114 (UpSampling2D (None, 96, 128, 16)  0           max_pooling2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_1495 (Conv2D)            (None, 96, 128, 8)   136         up_sampling2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_1496 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1495[0][0]
# __________________________________________________________________________________________________
# conv2d_1497 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1496[0][0]
# __________________________________________________________________________________________________
# conv2d_1498 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1497[0][0]
# __________________________________________________________________________________________________
# add_258 (Add)                   (None, 96, 128, 16)  0           conv2d_1498[0][0]
#                                                                  up_sampling2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_1499 (Conv2D)            (None, 96, 128, 8)   136         add_258[0][0]
# __________________________________________________________________________________________________
# conv2d_1500 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1499[0][0]
# __________________________________________________________________________________________________
# conv2d_1501 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1500[0][0]
# __________________________________________________________________________________________________
# conv2d_1502 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1501[0][0]
# __________________________________________________________________________________________________
# add_259 (Add)                   (None, 96, 128, 16)  0           conv2d_1502[0][0]
#                                                                  add_258[0][0]
# __________________________________________________________________________________________________
# conv2d_1503 (Conv2D)            (None, 96, 128, 8)   136         add_259[0][0]
# __________________________________________________________________________________________________
# conv2d_1504 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1503[0][0]
# __________________________________________________________________________________________________
# conv2d_1505 (Conv2D)            (None, 96, 128, 8)   328         conv2d_1504[0][0]
# __________________________________________________________________________________________________
# conv2d_1506 (Conv2D)            (None, 96, 128, 16)  144         conv2d_1505[0][0]
# __________________________________________________________________________________________________
# add_260 (Add)                   (None, 96, 128, 16)  0           conv2d_1506[0][0]
#                                                                  add_259[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_115 (UpSampling2D (None, 192, 256, 16) 0           add_260[0][0]
# __________________________________________________________________________________________________
# conv2d_1507 (Conv2D)            (None, 192, 256, 8)  136         up_sampling2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_1508 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1507[0][0]
# __________________________________________________________________________________________________
# conv2d_1509 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1508[0][0]
# __________________________________________________________________________________________________
# conv2d_1510 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1509[0][0]
# __________________________________________________________________________________________________
# add_261 (Add)                   (None, 192, 256, 16) 0           conv2d_1510[0][0]
#                                                                  up_sampling2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_1511 (Conv2D)            (None, 192, 256, 8)  136         add_261[0][0]
# __________________________________________________________________________________________________
# conv2d_1512 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1511[0][0]
# __________________________________________________________________________________________________
# conv2d_1513 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1512[0][0]
# __________________________________________________________________________________________________
# conv2d_1514 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1513[0][0]
# __________________________________________________________________________________________________
# add_262 (Add)                   (None, 192, 256, 16) 0           conv2d_1514[0][0]
#                                                                  add_261[0][0]
# __________________________________________________________________________________________________
# conv2d_1515 (Conv2D)            (None, 192, 256, 8)  136         add_262[0][0]
# __________________________________________________________________________________________________
# conv2d_1516 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1515[0][0]
# __________________________________________________________________________________________________
# conv2d_1517 (Conv2D)            (None, 192, 256, 8)  328         conv2d_1516[0][0]
# __________________________________________________________________________________________________
# conv2d_1518 (Conv2D)            (None, 192, 256, 16) 144         conv2d_1517[0][0]
# __________________________________________________________________________________________________
# add_263 (Add)                   (None, 192, 256, 16) 0           conv2d_1518[0][0]
#                                                                  add_262[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_116 (UpSampling2D (None, 384, 512, 16) 0           add_263[0][0]
# __________________________________________________________________________________________________
# conv2d_1519 (Conv2D)            (None, 384, 512, 8)  136         up_sampling2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_1520 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1519[0][0]
# __________________________________________________________________________________________________
# conv2d_1521 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1520[0][0]
# __________________________________________________________________________________________________
# conv2d_1522 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1521[0][0]
# __________________________________________________________________________________________________
# add_264 (Add)                   (None, 384, 512, 16) 0           conv2d_1522[0][0]
#                                                                  up_sampling2d_116[0][0]
# __________________________________________________________________________________________________
# conv2d_1523 (Conv2D)            (None, 384, 512, 8)  136         add_264[0][0]
# __________________________________________________________________________________________________
# conv2d_1524 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1523[0][0]
# __________________________________________________________________________________________________
# conv2d_1525 (Conv2D)            (None, 384, 512, 8)  328         conv2d_1524[0][0]
# __________________________________________________________________________________________________
# conv2d_1526 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1525[0][0]
# __________________________________________________________________________________________________
# conv2d_1530 (Conv2D)            (None, 384, 512, 16) 144         conv2d_1525[0][0]
# __________________________________________________________________________________________________
# add_265 (Add)                   (None, 384, 512, 16) 0           conv2d_1526[0][0]
#                                                                  add_264[0][0]
# __________________________________________________________________________________________________
# add_266 (Add)                   (None, 384, 512, 16) 0           conv2d_1530[0][0]
#                                                                  add_265[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_117 (UpSampling2D (None, 768, 1024, 16 0           add_266[0][0]
# __________________________________________________________________________________________________
# conv2d_1531 (Conv2D)            (None, 768, 1024, 8) 136         up_sampling2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_1532 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1531[0][0]
# __________________________________________________________________________________________________
# conv2d_1533 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1532[0][0]
# __________________________________________________________________________________________________
# conv2d_1534 (Conv2D)            (None, 768, 1024, 16 144         conv2d_1533[0][0]
# __________________________________________________________________________________________________
# add_267 (Add)                   (None, 768, 1024, 16 0           conv2d_1534[0][0]
#                                                                  up_sampling2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_1535 (Conv2D)            (None, 768, 1024, 8) 136         add_267[0][0]
# __________________________________________________________________________________________________
# conv2d_1536 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1535[0][0]
# __________________________________________________________________________________________________
# conv2d_1537 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1536[0][0]
# __________________________________________________________________________________________________
# conv2d_1538 (Conv2D)            (None, 768, 1024, 16 144         conv2d_1537[0][0]
# __________________________________________________________________________________________________
# add_268 (Add)                   (None, 768, 1024, 16 0           conv2d_1538[0][0]
#                                                                  add_267[0][0]
# __________________________________________________________________________________________________
# conv2d_1539 (Conv2D)            (None, 768, 1024, 8) 136         add_268[0][0]
# __________________________________________________________________________________________________
# conv2d_1540 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1539[0][0]
# __________________________________________________________________________________________________
# conv2d_1541 (Conv2D)            (None, 768, 1024, 8) 328         conv2d_1540[0][0]
# __________________________________________________________________________________________________
# conv2d_1542 (Conv2D)            (None, 768, 1024, 16 144         conv2d_1541[0][0]
# __________________________________________________________________________________________________
# add_269 (Add)                   (None, 768, 1024, 16 0           conv2d_1542[0][0]
#                                                                  add_268[0][0]
# __________________________________________________________________________________________________
# 102/102 [==============================] - 493s 5s/step - loss: 0.1367 - accuracy: 0.9476 - meanIoU: 0.2621 - val_loss: 0.4473 - val_accuracy: 0.8167 - val_meanIoU: 0.2184
# Epoch 15/100
# 102/102 [==============================] - 495s 5s/step - loss: 0.1362 - accuracy: 0.9477 - meanIoU: 0.2651 - val_loss: 0.4281 - val_accuracy: 0.8168 - val_meanIoU: 0.2239
# Epoch 16/100
# 102/102 [==============================] - 491s 5s/step - loss: 0.1342 - accuracy: 0.9486 - meanIoU: 0.2717 - val_loss: 0.3680 - val_accuracy: 0.8377 - val_meanIoU: 0.2299
# Epoch 17/100
# 102/102 [==============================] - 490s 5s/step - loss: 0.1337 - accuracy: 0.9487 - meanIoU: 0.2742 - val_loss: 0.3878 - val_accuracy: 0.8328 - val_meanIoU: 0.2372
# Epoch 18/100
# 102/102 [==============================] - 494s 5s/step - loss: 0.1303 - accuracy: 0.9500 - meanIoU: 0.2834 - val_loss: 0.3290 - val_accuracy: 0.8549 - val_meanIoU: 0.2403
# Epoch 19/100
# 102/102 [==============================] - 491s 5s/step - loss: 0.1293 - accuracy: 0.9502 - meanIoU: 0.2866 - val_loss: 0.3406 - val_accuracy: 0.8507 - val_meanIoU: 0.2461
# Epoch 20/100
# 102/102 [==============================] - 507s 5s/step - loss: 0.1265 - accuracy: 0.9511 - meanIoU: 0.2930 - val_loss: 0.3118 - val_accuracy: 0.8626 - val_meanIoU: 0.2464
# Epoch 21/100
# 102/102 [==============================] - 521s 5s/step - loss: 0.1256 - accuracy: 0.9513 - meanIoU: 0.2954 - val_loss: 0.3043 - val_accuracy: 0.8657 - val_meanIoU: 0.2506
# Epoch 22/100
# 102/102 [==============================] - 521s 5s/step - loss: 0.1235 - accuracy: 0.9520 - meanIoU: 0.3002 - val_loss: 0.2783 - val_accuracy: 0.8779 - val_meanIoU: 0.2492
# Epoch 23/100
# 102/102 [==============================] - 520s 5s/step - loss: 0.1224 - accuracy: 0.9523 - meanIoU: 0.3031 - val_loss: 0.2690 - val_accuracy: 0.8838 - val_meanIoU: 0.2512
# Epoch 24/100
# 102/102 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9528 - meanIoU: 0.3078

# %%
[model, history] = train_bonnet()
# Out:
# --------------------------------------------
# Image heigth                      ---> 768
# Image width                       ---> 1024
# Batch size                        ---> 6
# Learning rate                     ---> 0.0005
# Number of epochs                  ---> 100
# Model checkpoint                  ---> True
# Visualize tensorboars             ---> False
# Early stopping                    ---> True
# Reduce learning rate on plateau   ---> True
# --------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5c1a7a0fe6a9> in <module>()
# ----> 1 [model, history] = train_bonnet()
#
# <ipython-input-1-9500eba5c2d4> in train_bonnet()
#      34   print('--------------------------------------------')
#      35
# ---> 36   [img_data_gen, mask_data_gen] = data_generator(apply_data_augmentation)
#      37
#      38   [train_dataset, dataset, valid_dataset, dataset_valid] = create_dataset(img_data_gen, mask_data_gen, img_h = img_h, img_w = img_w, bs = bs, num_classes = num_classes)
#
# NameError: name 'data_generator' is not defined

# %% [markdown]
# # Compute prediction

# %%
apply_data_augmentation = True

img_h = 768
img_w = 1024

num_classes = 3

bs = 6

[img_data_gen, mask_data_gen] = data_generator(apply_data_augmentation)

[train_dataset, dataset, valid_dataset, dataset_valid] = create_dataset(img_data_gen, mask_data_gen, img_h = img_h, img_w = img_w, bs = bs, num_classes = num_classes)

model = define_bonnet(input_size = (img_h, img_w, 3))


exps_dir = os.path.join('/content/drive/My Drive/Challenge_2/', 'segmentation_experiments')
model_name = 'bonnet_rect'
exp_dir = os.path.join(exps_dir, model_name)
ckpt_dir = os.path.join(exp_dir, 'ckpts')
latest = tf.train.latest_checkpoint(ckpt_dir)
print(latest)
model.load_weights(latest)

#model = compile_model(model, lr = lr)
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 768, 1024, 3 0
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 768, 1024, 16 1216        input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 768, 1024, 16 64          conv2d_294[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 768, 1024, 16 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 768, 1024, 8) 136         re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_295[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_296[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 768, 1024, 16 144         conv2d_297[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 768, 1024, 16 0           conv2d_298[0][0]
#                                                                  re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 768, 1024, 8) 136         add_72[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_299[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_300[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 768, 1024, 16 144         conv2d_301[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 768, 1024, 16 0           conv2d_302[0][0]
#                                                                  add_72[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 768, 1024, 8) 136         add_73[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_303[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_304[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, 768, 1024, 16 144         conv2d_305[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 768, 1024, 16 0           conv2d_306[0][0]
#                                                                  add_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 384, 512, 16) 0           add_74[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, 384, 512, 8)  136         max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, 384, 512, 8)  328         conv2d_307[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 384, 512, 8)  328         conv2d_308[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 384, 512, 16) 144         conv2d_309[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 384, 512, 16) 0           conv2d_310[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_311 (Conv2D)             (None, 384, 512, 8)  136         add_75[0][0]
# __________________________________________________________________________________________________
# conv2d_312 (Conv2D)             (None, 384, 512, 8)  328         conv2d_311[0][0]
# __________________________________________________________________________________________________
# conv2d_313 (Conv2D)             (None, 384, 512, 8)  328         conv2d_312[0][0]
# __________________________________________________________________________________________________
# conv2d_314 (Conv2D)             (None, 384, 512, 16) 144         conv2d_313[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 384, 512, 16) 0           conv2d_314[0][0]
#                                                                  add_75[0][0]
# __________________________________________________________________________________________________
# conv2d_315 (Conv2D)             (None, 384, 512, 8)  136         add_76[0][0]
# __________________________________________________________________________________________________
# conv2d_316 (Conv2D)             (None, 384, 512, 8)  328         conv2d_315[0][0]
# __________________________________________________________________________________________________
# conv2d_317 (Conv2D)             (None, 384, 512, 8)  328         conv2d_316[0][0]
# __________________________________________________________________________________________________
# conv2d_318 (Conv2D)             (None, 384, 512, 16) 144         conv2d_317[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 384, 512, 16) 0           conv2d_318[0][0]
#                                                                  add_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 192, 256, 16) 0           add_77[0][0]
# __________________________________________________________________________________________________
# conv2d_319 (Conv2D)             (None, 192, 256, 8)  136         max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_320 (Conv2D)             (None, 192, 256, 8)  328         conv2d_319[0][0]
# __________________________________________________________________________________________________
# conv2d_321 (Conv2D)             (None, 192, 256, 8)  328         conv2d_320[0][0]
# __________________________________________________________________________________________________
# conv2d_322 (Conv2D)             (None, 192, 256, 16) 144         conv2d_321[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 192, 256, 16) 0           conv2d_322[0][0]
#                                                                  max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_323 (Conv2D)             (None, 192, 256, 8)  136         add_78[0][0]
# __________________________________________________________________________________________________
# conv2d_324 (Conv2D)             (None, 192, 256, 8)  328         conv2d_323[0][0]
# __________________________________________________________________________________________________
# conv2d_325 (Conv2D)             (None, 192, 256, 8)  328         conv2d_324[0][0]
# __________________________________________________________________________________________________
# conv2d_326 (Conv2D)             (None, 192, 256, 16) 144         conv2d_325[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 192, 256, 16) 0           conv2d_326[0][0]
#                                                                  add_78[0][0]
# __________________________________________________________________________________________________
# conv2d_327 (Conv2D)             (None, 192, 256, 8)  136         add_79[0][0]
# __________________________________________________________________________________________________
# conv2d_328 (Conv2D)             (None, 192, 256, 8)  328         conv2d_327[0][0]
# __________________________________________________________________________________________________
# conv2d_329 (Conv2D)             (None, 192, 256, 8)  328         conv2d_328[0][0]
# __________________________________________________________________________________________________
# conv2d_330 (Conv2D)             (None, 192, 256, 16) 144         conv2d_329[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 192, 256, 16) 0           conv2d_330[0][0]
#                                                                  add_79[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 96, 128, 16)  0           add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_331 (Conv2D)             (None, 96, 128, 8)   136         max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_332 (Conv2D)             (None, 96, 128, 8)   328         conv2d_331[0][0]
# __________________________________________________________________________________________________
# conv2d_333 (Conv2D)             (None, 96, 128, 8)   328         conv2d_332[0][0]
# __________________________________________________________________________________________________
# conv2d_334 (Conv2D)             (None, 96, 128, 16)  144         conv2d_333[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 96, 128, 16)  0           conv2d_334[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_335 (Conv2D)             (None, 96, 128, 8)   136         add_81[0][0]
# __________________________________________________________________________________________________
# conv2d_336 (Conv2D)             (None, 96, 128, 8)   328         conv2d_335[0][0]
# __________________________________________________________________________________________________
# conv2d_337 (Conv2D)             (None, 96, 128, 8)   328         conv2d_336[0][0]
# __________________________________________________________________________________________________
# conv2d_338 (Conv2D)             (None, 96, 128, 16)  144         conv2d_337[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 96, 128, 16)  0           conv2d_338[0][0]
#                                                                  add_81[0][0]
# __________________________________________________________________________________________________
# conv2d_339 (Conv2D)             (None, 96, 128, 8)   136         add_82[0][0]
# __________________________________________________________________________________________________
# conv2d_340 (Conv2D)             (None, 96, 128, 8)   328         conv2d_339[0][0]
# __________________________________________________________________________________________________
# conv2d_341 (Conv2D)             (None, 96, 128, 8)   328         conv2d_340[0][0]
# __________________________________________________________________________________________________
# conv2d_342 (Conv2D)             (None, 96, 128, 16)  144         conv2d_341[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 96, 128, 16)  0           conv2d_342[0][0]
#                                                                  add_82[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 48, 64, 16)   0           add_83[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 96, 128, 16)  0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_343 (Conv2D)             (None, 96, 128, 8)   136         up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_344 (Conv2D)             (None, 96, 128, 8)   328         conv2d_343[0][0]
# __________________________________________________________________________________________________
# conv2d_345 (Conv2D)             (None, 96, 128, 8)   328         conv2d_344[0][0]
# __________________________________________________________________________________________________
# conv2d_346 (Conv2D)             (None, 96, 128, 16)  144         conv2d_345[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 96, 128, 16)  0           conv2d_346[0][0]
#                                                                  up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_347 (Conv2D)             (None, 96, 128, 8)   136         add_84[0][0]
# __________________________________________________________________________________________________
# conv2d_348 (Conv2D)             (None, 96, 128, 8)   328         conv2d_347[0][0]
# __________________________________________________________________________________________________
# conv2d_349 (Conv2D)             (None, 96, 128, 8)   328         conv2d_348[0][0]
# __________________________________________________________________________________________________
# conv2d_350 (Conv2D)             (None, 96, 128, 16)  144         conv2d_349[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 96, 128, 16)  0           conv2d_350[0][0]
#                                                                  add_84[0][0]
# __________________________________________________________________________________________________
# conv2d_351 (Conv2D)             (None, 96, 128, 8)   136         add_85[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 96, 128, 8)   328         conv2d_351[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 96, 128, 8)   328         conv2d_352[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 96, 128, 16)  144         conv2d_353[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 96, 128, 16)  0           conv2d_354[0][0]
#                                                                  add_85[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 192, 256, 16) 0           add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 192, 256, 8)  136         up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 192, 256, 8)  328         conv2d_355[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 192, 256, 8)  328         conv2d_356[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 192, 256, 16) 144         conv2d_357[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 192, 256, 16) 0           conv2d_358[0][0]
#                                                                  up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 192, 256, 8)  136         add_87[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 192, 256, 8)  328         conv2d_359[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 192, 256, 8)  328         conv2d_360[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 192, 256, 16) 144         conv2d_361[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 192, 256, 16) 0           conv2d_362[0][0]
#                                                                  add_87[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 192, 256, 8)  136         add_88[0][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, 192, 256, 8)  328         conv2d_363[0][0]
# __________________________________________________________________________________________________
# conv2d_365 (Conv2D)             (None, 192, 256, 8)  328         conv2d_364[0][0]
# __________________________________________________________________________________________________
# conv2d_366 (Conv2D)             (None, 192, 256, 16) 144         conv2d_365[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 192, 256, 16) 0           conv2d_366[0][0]
#                                                                  add_88[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 384, 512, 16) 0           add_89[0][0]
# __________________________________________________________________________________________________
# conv2d_367 (Conv2D)             (None, 384, 512, 8)  136         up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_368 (Conv2D)             (None, 384, 512, 8)  328         conv2d_367[0][0]
# __________________________________________________________________________________________________
# conv2d_369 (Conv2D)             (None, 384, 512, 8)  328         conv2d_368[0][0]
# __________________________________________________________________________________________________
# conv2d_370 (Conv2D)             (None, 384, 512, 16) 144         conv2d_369[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 384, 512, 16) 0           conv2d_370[0][0]
#                                                                  up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_371 (Conv2D)             (None, 384, 512, 8)  136         add_90[0][0]
# __________________________________________________________________________________________________
# conv2d_372 (Conv2D)             (None, 384, 512, 8)  328         conv2d_371[0][0]
# __________________________________________________________________________________________________
# conv2d_373 (Conv2D)             (None, 384, 512, 8)  328         conv2d_372[0][0]
# __________________________________________________________________________________________________
# conv2d_374 (Conv2D)             (None, 384, 512, 16) 144         conv2d_373[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, 384, 512, 16) 144         conv2d_373[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 384, 512, 16) 0           conv2d_374[0][0]
#                                                                  add_90[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 384, 512, 16) 0           conv2d_378[0][0]
#                                                                  add_91[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 768, 1024, 16 0           add_92[0][0]
# __________________________________________________________________________________________________
# conv2d_379 (Conv2D)             (None, 768, 1024, 8) 136         up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_380 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_379[0][0]
# __________________________________________________________________________________________________
# conv2d_381 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_380[0][0]
# __________________________________________________________________________________________________
# conv2d_382 (Conv2D)             (None, 768, 1024, 16 144         conv2d_381[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 768, 1024, 16 0           conv2d_382[0][0]
#                                                                  up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_383 (Conv2D)             (None, 768, 1024, 8) 136         add_93[0][0]
# __________________________________________________________________________________________________
# conv2d_384 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_383[0][0]
# __________________________________________________________________________________________________
# conv2d_385 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_384[0][0]
# __________________________________________________________________________________________________
# conv2d_386 (Conv2D)             (None, 768, 1024, 16 144         conv2d_385[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 768, 1024, 16 0           conv2d_386[0][0]
#                                                                  add_93[0][0]
# __________________________________________________________________________________________________
# conv2d_387 (Conv2D)             (None, 768, 1024, 8) 136         add_94[0][0]
# __________________________________________________________________________________________________
# conv2d_388 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_387[0][0]
# __________________________________________________________________________________________________
# conv2d_389 (Conv2D)             (None, 768, 1024, 8) 328         conv2d_388[0][0]
# __________________________________________________________________________________________________
# conv2d_390 (Conv2D)             (None, 768, 1024, 16 144         conv2d_389[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 768, 1024, 16 0           conv2d_390[0][0]
#                                                                  add_94[0][0]
# __________________________________________________________________________________________________
# conv2d_391 (Conv2D)             (None, 768, 1024, 3) 51          add_95[0][0]
# ==================================================================================================
# Total params: 23,003
# Trainable params: 22,971
# Non-trainable params: 32
# __________________________________________________________________________________________________
# /content/drive/My Drive/Challenge_2/segmentation_experiments/bonnet_rect/ckpts/cp_30.ckpt

# %%
import time
import matplotlib.pyplot as plt

from PIL import Image

# %matplotlib inline

iterator = iter(valid_dataset)

# %%
image, target = next(iterator)

# %%
fig, ax = plt.subplots(1, 3, figsize=(8, 8))
fig.show()

image = image[0]
target = target[0, ..., 0]

out_sigmoid = model.predict(x=tf.expand_dims(image, 0))

# Get predicted class as the index corresponding to the maximum value in the vector probability
# predicted_class = tf.cast(out_sigmoid > score_th, tf.int32)
# predicted_class = predicted_class[0, ..., 0]
predicted_class = tf.argmax(out_sigmoid, -1)

out_sigmoid.shape

predicted_class = predicted_class[0, ...]

# Assign colors (just for visualization)
target_img = np.zeros([target.shape[0], target.shape[1], 3])
prediction_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, 3):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

prediction_img[np.where(predicted_class == 0)] = [0, 0, 0]
for i in range(1, 3):
  prediction_img[np.where(predicted_class == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(image))
ax[1].imshow(np.uint8(target_img))
ax[2].imshow(np.uint8(prediction_img))

fig.canvas.draw()
time.sleep(1)
# Out:
# (1, 768, 1024, 3)

# %% [markdown]
# # Training

# %% [markdown]
# # Execution

# %% [markdown]
# # Result csv

# %%
def rle_encode(img):
  '''
  img: numpy array, 1 - foreground, 0 - background
  Returns run length as string formatted
  '''
  pixels = img.flatten()
  pixels = np.concatenate([[0], pixels, [0]])
  runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
  runs[1::2] -= runs[::2]
  
  return ' '.join(str(x) for x in runs)

# %%
import os
import json
import numpy as np
from PIL import Image

    # The submission file will be a zip file containing the a
    # submission.json file.

    # It must have the following structure:

    # - image name (without any extension, e.g., png, jpg, etc.)
    #   - shape: shape of the original image as list [Height, Width]
    #   - team: team of the original image. One in {'Bipbip', 'Pead', 'Roseau', 'Weedelec'}
    #   - crop: crop of the original image. One in {'Haricot', 'Mais'}
    #   - segmentation: prediction (as a dict)
    #     - crop: RLE encoded crop segmentation (no weed)
    #     - weed: RLE encoded weed segmentation (no crop)

    # Please refer to the folder structure of the given dataset to fill
    # the team and crop keys.

teams = ['Bipbip', 'Pead', 'Roseau', 'Weedelec']
plants = ['Haricot', 'Mais']

submission_dict = {}

for t in teams:
  for p in plants:

    tmp_path = '/content/Development_Dataset/Test_Dev/' + t + '/' + p + '/' + 'Images'
    
    image_filenames = os.listdir(tmp_path)

    for img_name in image_filenames:
      
      tmp_path = '/content/Development_Dataset/Test_Dev/' + t + '/' + p + '/' + 'Images'
      tmp_path = os.path.join(tmp_path, img_name)
      
      img_name = img_name.split('.')[0]

      submission_dict[img_name] = {}
      submission_dict[img_name]['shape'] = mask_arr.shape
      submission_dict[img_name]['team'] = t
      submission_dict[img_name]['crop'] = p
      submission_dict[img_name]['segmentation'] = {}

      img = Image.open(tmp_path).convert('RGB')
      #img = img.resize((img_h, img_w)) # ??????????????????????????????????????????????????????????????????

      img_array = np.array(img)
      img_array = np.expand_dims(img_array, 0) # insert batch dimension

      # Data Normalization
      img_array = img_array / 255.

      # Prediction from the model
      mask_arr = model.predict(x=img_array)

      # RLE encoding
      # crop
      rle_encoded_crop = rle_encode(mask_arr == 1)
      # weed
      rle_encoded_weed = rle_encode(mask_arr == 2)

      submission_dict[img_name]['segmentation']['crop'] = rle_encoded_crop
      submission_dict[img_name]['segmentation']['weed'] = rle_encoded_weed

# Finally, save the results into the submission.json file
with open('/content/submission.json', 'w') as f:
  json.dump(submission_dict, f)

! mkdir '/content/drive/My Drive/Challenge_2/submission'
! cp '/content/submission.json'

# %%
! ls '/content/drive/My Drive/Challenge_2/submission'

# %%
# ---------------------------------------
# Save the model trained with fine tuning
# ---------------------------------------
#! mkdir '/content/drive/My Drive/Challenge_1/model'
#! mkdir '/content/drive/My Drive/Challenge_1/model/EffNet_B7_dense_16_NOdropout_fine_tuning_block5-6-7'
#model.save('/content/drive/My Drive/Challenge_1/model/EffNet_B7_dense_16_NOdropout_fine_tuning_block5-6-7')

# %%
'''
Script to check dimension of the images

# -----------------------------------------------
teams = ['Bipbip', 'Pead', 'Roseau', 'Weedelec']
plants = ['Haricot', 'Mais']

submission_dict = {}

for t in teams:
  for p in plants:
    tmp_path = '/content/Development_Dataset/Test_Dev/' + t + '/' + p + '/' + 'Images'
    image_filenames = os.listdir(tmp_path)

    for img_name in image_filenames:

      tmp_path = '/content/Development_Dataset/Test_Dev/' + t + '/' + p + '/' + 'Images'
      tmp_path = os.path.join(tmp_path, str(img_name))
      
      img = Image.open(tmp_path).convert('RGB')
      img_array = np.array(img)

      img_name = img_name.split('.')[0]

      submission_dict[img_name] = {}
      submission_dict[img_name]['shape'] = img_array.shape
      submission_dict[img_name]['team'] = t
      submission_dict[img_name]['crop'] = p

# -----------------------------------------------------------------------
submission
'''
